# %%
####################################


#THIS FIRST SECTION WILL IMPORT THE TRAINING DATA AND SETUP THE INFORMATION FOR TRAINING


####################################

# %%
#import libraries you used 
import os
import pandas as pd
import zipfile
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
import torchvision
import tarfile
from PIL import Image
from torchvision.datasets.utils import download_url
from torch.utils.data import random_split
from torchvision import transforms
import shutil
from sklearn.metrics import f1_score
from torch.utils.data.dataloader import DataLoader


## Import the data into the document
image_dir = '/Users/louieburns/Library/CloudStorage/OneDrive-UniversityofLeeds/Year 3/AI and Machine Learning/Term 1/Coursework 1/Actual Coursework/dataoriginal/images'
image_files = [f for f in os.listdir(image_dir) if f.endswith('.jpg')]


## CREATE A FILE WITH THE DESIRED IMAGES ONLY

# Define the classifications to filter and their numeric mappings
classification_mapping = {
    "Embraer E-Jet": 0,
    "Boeing 737": 1,
    "A320": 2,
    "Cessna Citation": 3,
    "Gulfstream": 4
}

# Define the file path
file_path = '/Users/louieburns/Library/CloudStorage/OneDrive-UniversityofLeeds/Year 3/AI and Machine Learning/Term 1/Coursework 1/Actual Coursework/dataoriginal/images_family_test.txt'
# Read the file and handle inconsistent line structures
data = []
with open(file_path, 'r') as file:
    for i, line in enumerate(file):
        parts = line.strip().split()
        if len(parts) >= 2:  # Ensure at least two fields exist
            number = parts[0]
            classification = ' '.join(parts[1:])  # Combine remaining parts
            data.append({"Number": number, "Classification": classification})
        else:
            print(f"Skipping invalid line {i + 1}: {line.strip()}")  # Debugging invalid lines

# Convert to a DataFrame
df = pd.DataFrame(data)

# Standardise the Classification column
df['Classification'] = df['Classification'].str.strip()  # Remove extra spaces
df['Classification'] = df['Classification'].str.title()  # Standardise capitalisation

# Add numeric labels and filter invalid classifications
df['Label'] = df['Classification'].map(classification_mapping)
df = df.dropna(subset=['Label']).reset_index(drop=True)  # Remove rows with invalid classifications

# Display the resulting DataFrame
print(df)

from collections import Counter

# Read the file and collect classifications
classifications = []
with open(file_path, 'r') as file:
    for line in file:
        parts = line.strip().split()
        if len(parts) >= 2:  # Ensure there are at least two fields
            classification = ' '.join(parts[1:]).strip()  # Combine fields after the first
            classifications.append(classification)

# Count the occurrences of each classification
classification_counts = Counter(classifications)

# Display the results
print("Classification Counts:")
for classification, count in classification_counts.items():
    print(f"{classification}: {count}")

# Count the occurrences of each classification in the filtered DataFrame
filtered_classification_counts = df['Classification'].value_counts()

# Display the results
print("Filtered Classification Counts:")
print(filtered_classification_counts)


## Create a folder with only the photos to keep

# Path to your folder containing images
image_folder_path = '/Users/louieburns/Library/CloudStorage/OneDrive-UniversityofLeeds/Year 3/AI and Machine Learning/Term 1/Coursework 1/Actual Coursework/dataoriginal/images'

relevant_codes = set(df['Number'])  # Convert to a set for faster lookup

# Initialize a list to hold image tensors
image_tensors = []

# Define the image transformation (resize and convert to tensor)
transform = transforms.Compose([
    transforms.Resize((224, 224)),  # Resize all images to a fixed size (e.g., 224x224)
    transforms.ToTensor()  # Convert image to PyTorch tensor
])

# Iterate over files in the folder
for image_file in os.listdir(image_folder_path):
    # Extract the numeric part of the file name (assuming it's the code)
    code = os.path.splitext(image_file)[0]
    if code in relevant_codes and image_file.endswith('.jpg'):
        # Load the image
        image_path = os.path.join(image_folder_path, image_file)
        img = Image.open(image_path).convert('RGB')  # Ensure 3 color channels (RGB)
        
        # Transform the image and append to the list
        tensor = transform(img)
        image_tensors.append(tensor)
        print(f"Loaded and transformed: {image_file}")

# Stack all tensors into a single tensor
if image_tensors:
    image_tensor_batch = torch.stack(image_tensors)
    print(f"Created a tensor of shape: {image_tensor_batch.shape}")
else:
    print("No images matched the criteria!")

# Example tensor shape: [num_images, channels, height, width]
# Out:
#       Number Classification  Label
# 0    0227058     Boeing 737    1.0
# 1    0950275     Boeing 737    1.0
# 2    0114122     Boeing 737    1.0
# 3    1754503     Boeing 737    1.0
# 4    0127648     Boeing 737    1.0
# ..       ...            ...    ...
# 630  0447762     Gulfstream    4.0
# 631  0396507     Gulfstream    4.0
# 632  2030079     Gulfstream    4.0
# 633  1063148     Gulfstream    4.0
# 634  0492487     Gulfstream    4.0
#
# [635 rows x 3 columns]
# Classification Counts:
# Boeing 707: 33
# Boeing 727: 33
# Boeing 737: 267
# Boeing 747: 133
# Boeing 757: 67
# Boeing 767: 100
# Boeing 777: 67
# A300: 33
# A310: 33
# A320: 134
# A330: 66
# A340: 134
# A380: 33
# ATR-42: 33
# ATR-72: 34
# An-12: 33
# BAE 146: 67
# BAE-125: 33
# Beechcraft 1900: 33
# Boeing 717: 34
# C-130: 33
# C-47: 33
# CRJ-200: 34
# CRJ-700: 66
# Cessna 172: 34
# Cessna 208: 33
# Cessna Citation: 67
# Challenger 600: 33
# DC-10: 33
# DC-3: 34
# DC-6: 33
# DC-8: 33
# DC-9: 34
# DH-82: 33
# DHC-1: 33
# DHC-6: 34
# Dash 8: 66
# DR-400: 34
# Dornier 328: 33
# Embraer E-Jet: 100
# EMB-120: 33
# Embraer ERJ 145: 67
# Embraer Legacy 600: 33
# Eurofighter Typhoon: 34
# F-16: 33
# F/A-18: 33
# Falcon 2000: 34
# Falcon 900: 33
# Fokker 100: 33
# Fokker 50: 34
# Fokker 70: 33
# Global Express: 33
# Gulfstream: 67
# Hawk T1: 33
# Il-76: 34
# L-1011: 33
# MD-11: 33
# MD-80: 67
# MD-90: 33
# Metroliner: 34
# King Air: 33
# PA-28: 33
# SR-20: 34
# Saab 2000: 33
# Saab 340: 33
# Spitfire: 34
# Tornado: 33
# Tu-134: 33
# Tu-154: 34
# Yak-42: 33
# Filtered Classification Counts:
# Classification
# Boeing 737         267
# A320               134
# Embraer E-Jet      100
# Cessna Citation     67
# Gulfstream          67
# Name: count, dtype: int64
# Loaded and transformed: 2221342.jpg
# Loaded and transformed: 1548400.jpg
# Loaded and transformed: 1107447.jpg
# Loaded and transformed: 1476061.jpg
# Loaded and transformed: 2227525.jpg
# Loaded and transformed: 1259554.jpg
# Loaded and transformed: 1698699.jpg
# Loaded and transformed: 0218033.jpg
# Loaded and transformed: 1142906.jpg
# Loaded and transformed: 1510253.jpg
# Loaded and transformed: 1119094.jpg
# Loaded and transformed: 1398526.jpg
# Loaded and transformed: 1768807.jpg
# Loaded and transformed: 1508811.jpg
# Loaded and transformed: 2002331.jpg
# Loaded and transformed: 1419049.jpg
# Loaded and transformed: 2190848.jpg
# Loaded and transformed: 1456004.jpg
# Loaded and transformed: 2211444.jpg
# Loaded and transformed: 1336582.jpg
# Loaded and transformed: 1251519.jpg
# Loaded and transformed: 1185069.jpg
# Loaded and transformed: 2228978.jpg
# Loaded and transformed: 1878567.jpg
# Loaded and transformed: 0447745.jpg
# Loaded and transformed: 1272698.jpg
# Loaded and transformed: 1879889.jpg
# Loaded and transformed: 0998786.jpg
# Loaded and transformed: 0918179.jpg
# Loaded and transformed: 0973082.jpg
# Loaded and transformed: 1940832.jpg
# Loaded and transformed: 1876402.jpg
# Loaded and transformed: 0225210.jpg
# Loaded and transformed: 1686317.jpg
# Loaded and transformed: 1403158.jpg
# Loaded and transformed: 0864663.jpg
# Loaded and transformed: 1115297.jpg
# Loaded and transformed: 1663628.jpg
# Loaded and transformed: 0496901.jpg
# Loaded and transformed: 1852007.jpg
# Loaded and transformed: 1676582.jpg
# Loaded and transformed: 0543870.jpg
# Loaded and transformed: 0950275.jpg
# Loaded and transformed: 1934357.jpg
# Loaded and transformed: 1927317.jpg
# Loaded and transformed: 0936133.jpg
# Loaded and transformed: 0944994.jpg
# Loaded and transformed: 0325574.jpg
# Loaded and transformed: 1086833.jpg
# Loaded and transformed: 1545325.jpg
# Loaded and transformed: 0097578.jpg
# Loaded and transformed: 1395798.jpg
# Loaded and transformed: 1078482.jpg
# Loaded and transformed: 1795553.jpg
# Loaded and transformed: 1879121.jpg
# Loaded and transformed: 1550106.jpg
# Loaded and transformed: 2191957.jpg
# Loaded and transformed: 2117298.jpg
# Loaded and transformed: 1085719.jpg
# Loaded and transformed: 1305611.jpg
# Loaded and transformed: 0412223.jpg
# Loaded and transformed: 1885833.jpg
# Loaded and transformed: 1146021.jpg
# Loaded and transformed: 1092270.jpg
# Loaded and transformed: 1358066.jpg
# Loaded and transformed: 1352205.jpg
# Loaded and transformed: 2137161.jpg
# Loaded and transformed: 1950559.jpg
# Loaded and transformed: 1723838.jpg
# Loaded and transformed: 0198104.jpg
# Loaded and transformed: 1295799.jpg
# Loaded and transformed: 2107061.jpg
# Loaded and transformed: 0062679.jpg
# Loaded and transformed: 1922722.jpg
# Loaded and transformed: 1444748.jpg
# Loaded and transformed: 1196360.jpg
# Loaded and transformed: 1967054.jpg
# Loaded and transformed: 1903505.jpg
# Loaded and transformed: 0361109.jpg
# Loaded and transformed: 1066524.jpg
# Loaded and transformed: 1736148.jpg
# Loaded and transformed: 0448049.jpg
# Loaded and transformed: 1418231.jpg
# Loaded and transformed: 1016570.jpg
# Loaded and transformed: 1358664.jpg
# Loaded and transformed: 0497629.jpg
# Loaded and transformed: 0523207.jpg
# Loaded and transformed: 1040656.jpg
# Loaded and transformed: 1279709.jpg
# Loaded and transformed: 1889566.jpg
# Loaded and transformed: 0957899.jpg
# Loaded and transformed: 1133684.jpg
# Loaded and transformed: 1496971.jpg
# Loaded and transformed: 1634373.jpg
# Loaded and transformed: 1261350.jpg
# Loaded and transformed: 0695327.jpg
# Loaded and transformed: 1535566.jpg
# Loaded and transformed: 1461862.jpg
# Loaded and transformed: 2145082.jpg
# Loaded and transformed: 1169979.jpg
# Loaded and transformed: 1597449.jpg
# Loaded and transformed: 1471641.jpg
# Loaded and transformed: 0701751.jpg
# Loaded and transformed: 1356890.jpg
# Loaded and transformed: 1471735.jpg
# Loaded and transformed: 0218801.jpg
# Loaded and transformed: 1771969.jpg
# Loaded and transformed: 0681541.jpg
# Loaded and transformed: 1062970.jpg
# Loaded and transformed: 1971194.jpg
# Loaded and transformed: 2195128.jpg
# Loaded and transformed: 2217839.jpg
# Loaded and transformed: 1088415.jpg
# Loaded and transformed: 0275806.jpg
# Loaded and transformed: 1139751.jpg
# Loaded and transformed: 0923504.jpg
# Loaded and transformed: 0702845.jpg
# Loaded and transformed: 1102089.jpg
# Loaded and transformed: 0668444.jpg
# Loaded and transformed: 2264828.jpg
# Loaded and transformed: 2007890.jpg
# Loaded and transformed: 2018768.jpg
# Loaded and transformed: 1529574.jpg
# Loaded and transformed: 0759316.jpg
# Loaded and transformed: 1088603.jpg
# Loaded and transformed: 1506226.jpg
# Loaded and transformed: 1351643.jpg
# Loaded and transformed: 1682001.jpg
# Loaded and transformed: 0796349.jpg
# Loaded and transformed: 2191945.jpg
# Loaded and transformed: 0972415.jpg
# Loaded and transformed: 0447769.jpg
# Loaded and transformed: 1244306.jpg
# Loaded and transformed: 0482804.jpg
# Loaded and transformed: 0730798.jpg
# Loaded and transformed: 2255571.jpg
# Loaded and transformed: 2135566.jpg
# Loaded and transformed: 1545068.jpg
# Loaded and transformed: 1783685.jpg
# Loaded and transformed: 2263029.jpg
# Loaded and transformed: 1903311.jpg
# Loaded and transformed: 2063913.jpg
# Loaded and transformed: 2038532.jpg
# Loaded and transformed: 1318450.jpg
# Loaded and transformed: 1696061.jpg
# Loaded and transformed: 1602628.jpg
# Loaded and transformed: 1520357.jpg
# Loaded and transformed: 1212753.jpg
# Loaded and transformed: 0713593.jpg
# Loaded and transformed: 2133249.jpg
# Loaded and transformed: 0494478.jpg
# Loaded and transformed: 2207626.jpg
# Loaded and transformed: 0357873.jpg
# Loaded and transformed: 1548404.jpg
# Loaded and transformed: 1139750.jpg
# Loaded and transformed: 1355815.jpg
# Loaded and transformed: 0713752.jpg
# Loaded and transformed: 1312536.jpg
# Loaded and transformed: 2173352.jpg
# Loaded and transformed: 2190977.jpg
# Loaded and transformed: 0880593.jpg
# Loaded and transformed: 1551668.jpg
# Loaded and transformed: 1759298.jpg
# Loaded and transformed: 0649605.jpg
# Loaded and transformed: 1461218.jpg
# Loaded and transformed: 0336540.jpg
# Loaded and transformed: 2067870.jpg
# Loaded and transformed: 1310123.jpg
# Loaded and transformed: 1570498.jpg
# Loaded and transformed: 1647313.jpg
# Loaded and transformed: 0675711.jpg
# Loaded and transformed: 1361876.jpg
# Loaded and transformed: 2128746.jpg
# Loaded and transformed: 1622762.jpg
# Loaded and transformed: 0582863.jpg
# Loaded and transformed: 1659448.jpg
# Loaded and transformed: 1950707.jpg
# Loaded and transformed: 1806227.jpg
# Loaded and transformed: 0104601.jpg
# Loaded and transformed: 1551279.jpg
# Loaded and transformed: 1366856.jpg
# Loaded and transformed: 2137129.jpg
# Loaded and transformed: 1361693.jpg
# Loaded and transformed: 0136472.jpg
# Loaded and transformed: 1335573.jpg
# Loaded and transformed: 1242658.jpg
# Loaded and transformed: 1063148.jpg
# Loaded and transformed: 2194912.jpg
# Loaded and transformed: 0176136.jpg
# Loaded and transformed: 1095184.jpg
# Loaded and transformed: 1529275.jpg
# Loaded and transformed: 0931601.jpg
# Loaded and transformed: 1055149.jpg
# Loaded and transformed: 1458698.jpg
# Loaded and transformed: 0308863.jpg
# Loaded and transformed: 0514744.jpg
# Loaded and transformed: 1807932.jpg
# Loaded and transformed: 0237107.jpg
# Loaded and transformed: 1927638.jpg
# Loaded and transformed: 0133440.jpg
# Loaded and transformed: 2006296.jpg
# Loaded and transformed: 1329158.jpg
# Loaded and transformed: 1364919.jpg
# Loaded and transformed: 1679201.jpg
# Loaded and transformed: 1372809.jpg
# Loaded and transformed: 1047407.jpg
# Loaded and transformed: 2220612.jpg
# Loaded and transformed: 1425707.jpg
# Loaded and transformed: 0257552.jpg
# Loaded and transformed: 1480422.jpg
# Loaded and transformed: 1172324.jpg
# Loaded and transformed: 1860176.jpg
# Loaded and transformed: 0958065.jpg
# Loaded and transformed: 1768872.jpg
# Loaded and transformed: 1838645.jpg
# Loaded and transformed: 2168374.jpg
# Loaded and transformed: 2183458.jpg
# Loaded and transformed: 1526019.jpg
# Loaded and transformed: 1537100.jpg
# Loaded and transformed: 2266336.jpg
# Loaded and transformed: 0741298.jpg
# Loaded and transformed: 1662032.jpg
# Loaded and transformed: 1641833.jpg
# Loaded and transformed: 1882508.jpg
# Loaded and transformed: 0882609.jpg
# Loaded and transformed: 1093247.jpg
# Loaded and transformed: 1224910.jpg
# Loaded and transformed: 1931271.jpg
# Loaded and transformed: 1258401.jpg
# Loaded and transformed: 0074246.jpg
# Loaded and transformed: 2023598.jpg
# Loaded and transformed: 1470663.jpg
# Loaded and transformed: 1758619.jpg
# Loaded and transformed: 0681537.jpg
# Loaded and transformed: 1611219.jpg
# Loaded and transformed: 1018933.jpg
# Loaded and transformed: 1129244.jpg
# Loaded and transformed: 1549035.jpg
# Loaded and transformed: 1055199.jpg
# Loaded and transformed: 1577681.jpg
# Loaded and transformed: 1958758.jpg
# Loaded and transformed: 2234272.jpg
# Loaded and transformed: 2057962.jpg
# Loaded and transformed: 0174054.jpg
# Loaded and transformed: 1762803.jpg
# Loaded and transformed: 1297843.jpg
# Loaded and transformed: 1468400.jpg
# Loaded and transformed: 1659671.jpg
# Loaded and transformed: 1468399.jpg
# Loaded and transformed: 0890396.jpg
# Loaded and transformed: 0218042.jpg
# Loaded and transformed: 1806208.jpg
# Loaded and transformed: 1647665.jpg
# Loaded and transformed: 0492487.jpg
# Loaded and transformed: 2164953.jpg
# Loaded and transformed: 0498140.jpg
# Loaded and transformed: 1080160.jpg
# Loaded and transformed: 0894324.jpg
# Loaded and transformed: 1281985.jpg
# Loaded and transformed: 1921311.jpg
# Loaded and transformed: 2056248.jpg
# Loaded and transformed: 1043473.jpg
# Loaded and transformed: 2160088.jpg
# Loaded and transformed: 1354835.jpg
# Loaded and transformed: 1032301.jpg
# Loaded and transformed: 1398436.jpg
# Loaded and transformed: 0688076.jpg
# Loaded and transformed: 2147231.jpg
# Loaded and transformed: 1953630.jpg
# Loaded and transformed: 0682201.jpg
# Loaded and transformed: 1565290.jpg
# Loaded and transformed: 1790921.jpg
# Loaded and transformed: 0460770.jpg
# Loaded and transformed: 2058107.jpg
# Loaded and transformed: 0795231.jpg
# Loaded and transformed: 2044260.jpg
# Loaded and transformed: 0083150.jpg
# Loaded and transformed: 2238661.jpg
# Loaded and transformed: 0951126.jpg
# Loaded and transformed: 2106086.jpg
# Loaded and transformed: 0880582.jpg
# Loaded and transformed: 2246817.jpg
# Loaded and transformed: 1901160.jpg
# Loaded and transformed: 2211026.jpg
# Loaded and transformed: 0862739.jpg
# Loaded and transformed: 1796759.jpg
# Loaded and transformed: 1077924.jpg
# Loaded and transformed: 0901473.jpg
# Loaded and transformed: 1861737.jpg
# Loaded and transformed: 1769000.jpg
# Loaded and transformed: 2229397.jpg
# Loaded and transformed: 0227058.jpg
# Loaded and transformed: 1565325.jpg
# Loaded and transformed: 0492490.jpg
# Loaded and transformed: 1218624.jpg
# Loaded and transformed: 1429846.jpg
# Loaded and transformed: 1330195.jpg
# Loaded and transformed: 1173014.jpg
# Loaded and transformed: 1288222.jpg
# Loaded and transformed: 1446516.jpg
# Loaded and transformed: 1376842.jpg
# Loaded and transformed: 1069925.jpg
# Loaded and transformed: 1807114.jpg
# Loaded and transformed: 1298958.jpg
# Loaded and transformed: 1966298.jpg
# Loaded and transformed: 1455998.jpg
# Loaded and transformed: 1658586.jpg
# Loaded and transformed: 1899099.jpg
# Loaded and transformed: 1691816.jpg
# Loaded and transformed: 2030079.jpg
# Loaded and transformed: 0072369.jpg
# Loaded and transformed: 1046468.jpg
# Loaded and transformed: 1709124.jpg
# Loaded and transformed: 1591312.jpg
# Loaded and transformed: 1304344.jpg
# Loaded and transformed: 1615914.jpg
# Loaded and transformed: 2245660.jpg
# Loaded and transformed: 1365786.jpg
# Loaded and transformed: 1471543.jpg
# Loaded and transformed: 2190740.jpg
# Loaded and transformed: 0446944.jpg
# Loaded and transformed: 0704268.jpg
# Loaded and transformed: 0764239.jpg
# Loaded and transformed: 1579853.jpg
# Loaded and transformed: 0979665.jpg
# Loaded and transformed: 1340279.jpg
# Loaded and transformed: 1222601.jpg
# Loaded and transformed: 0076843.jpg
# Loaded and transformed: 1143441.jpg
# Loaded and transformed: 1377012.jpg
# Loaded and transformed: 2069707.jpg
# Loaded and transformed: 1423426.jpg
# Loaded and transformed: 1655252.jpg
# Loaded and transformed: 2192006.jpg
# Loaded and transformed: 0699565.jpg
# Loaded and transformed: 2223311.jpg
# Loaded and transformed: 1546282.jpg
# Loaded and transformed: 1244625.jpg
# Loaded and transformed: 1398982.jpg
# Loaded and transformed: 2253635.jpg
# Loaded and transformed: 1813838.jpg
# Loaded and transformed: 2161158.jpg
# Loaded and transformed: 0558343.jpg
# Loaded and transformed: 0305545.jpg
# Loaded and transformed: 1367016.jpg
# Loaded and transformed: 1385093.jpg
# Loaded and transformed: 0147057.jpg
# Loaded and transformed: 0746112.jpg
# Loaded and transformed: 0454592.jpg
# Loaded and transformed: 1810855.jpg
# Loaded and transformed: 1454446.jpg
# Loaded and transformed: 1871273.jpg
# Loaded and transformed: 1636521.jpg
# Loaded and transformed: 1966096.jpg
# Loaded and transformed: 1469738.jpg
# Loaded and transformed: 1110805.jpg
# Loaded and transformed: 1881962.jpg
# Loaded and transformed: 0717995.jpg
# Loaded and transformed: 1842040.jpg
# Loaded and transformed: 0182727.jpg
# Loaded and transformed: 1178011.jpg
# Loaded and transformed: 1891967.jpg
# Loaded and transformed: 1561990.jpg
# Loaded and transformed: 2170860.jpg
# Loaded and transformed: 1113895.jpg
# Loaded and transformed: 1561986.jpg
# Loaded and transformed: 1739566.jpg
# Loaded and transformed: 1363662.jpg
# Loaded and transformed: 1469699.jpg
# Loaded and transformed: 1810937.jpg
# Loaded and transformed: 2229401.jpg
# Loaded and transformed: 0847415.jpg
# Loaded and transformed: 1163792.jpg
# Loaded and transformed: 1393354.jpg
# Loaded and transformed: 0987802.jpg
# Loaded and transformed: 1806210.jpg
# Loaded and transformed: 1713238.jpg
# Loaded and transformed: 1552592.jpg
# Loaded and transformed: 1237623.jpg
# Loaded and transformed: 1169718.jpg
# Loaded and transformed: 1308404.jpg
# Loaded and transformed: 1577934.jpg
# Loaded and transformed: 0770474.jpg
# Loaded and transformed: 0890827.jpg
# Loaded and transformed: 1291783.jpg
# Loaded and transformed: 2033184.jpg
# Loaded and transformed: 0669870.jpg
# Loaded and transformed: 1796970.jpg
# Loaded and transformed: 0962643.jpg
# Loaded and transformed: 0875303.jpg
# Loaded and transformed: 1100234.jpg
# Loaded and transformed: 2180164.jpg
# Loaded and transformed: 1714026.jpg
# Loaded and transformed: 1535044.jpg
# Loaded and transformed: 1619270.jpg
# Loaded and transformed: 1163793.jpg
# Loaded and transformed: 2241970.jpg
# Loaded and transformed: 0259167.jpg
# Loaded and transformed: 1687909.jpg
# Loaded and transformed: 1124590.jpg
# Loaded and transformed: 0218852.jpg
# Loaded and transformed: 0851302.jpg
# Loaded and transformed: 1606542.jpg
# Loaded and transformed: 1935750.jpg
# Loaded and transformed: 0939519.jpg
# Loaded and transformed: 0944257.jpg
# Loaded and transformed: 0361611.jpg
# Loaded and transformed: 1336460.jpg
# Loaded and transformed: 0857549.jpg
# Loaded and transformed: 0944247.jpg
# Loaded and transformed: 1238449.jpg
# Loaded and transformed: 1091663.jpg
# Loaded and transformed: 1586117.jpg
# Loaded and transformed: 1900937.jpg
# Loaded and transformed: 1910729.jpg
# Loaded and transformed: 1363673.jpg
# Loaded and transformed: 0063284.jpg
# Loaded and transformed: 1860580.jpg
# Loaded and transformed: 1268068.jpg
# Loaded and transformed: 0673596.jpg
# Loaded and transformed: 0694480.jpg
# Loaded and transformed: 1008903.jpg
# Loaded and transformed: 2173639.jpg
# Loaded and transformed: 1421021.jpg
# Loaded and transformed: 1110779.jpg
# Loaded and transformed: 0807961.jpg
# Loaded and transformed: 1510217.jpg
# Loaded and transformed: 2134406.jpg
# Loaded and transformed: 1296201.jpg
# Loaded and transformed: 2139678.jpg
# Loaded and transformed: 0522417.jpg
# Loaded and transformed: 1545982.jpg
# Loaded and transformed: 1559373.jpg
# Loaded and transformed: 1559372.jpg
# Loaded and transformed: 0175746.jpg
# Loaded and transformed: 0075752.jpg
# Loaded and transformed: 1351213.jpg
# Loaded and transformed: 1393634.jpg
# Loaded and transformed: 2116329.jpg
# Loaded and transformed: 1788034.jpg
# Loaded and transformed: 2152231.jpg
# Loaded and transformed: 1381998.jpg
# Loaded and transformed: 2126017.jpg
# Loaded and transformed: 2187801.jpg
# Loaded and transformed: 2054442.jpg
# Loaded and transformed: 0965713.jpg
# Loaded and transformed: 2223909.jpg
# Loaded and transformed: 1943358.jpg
# Loaded and transformed: 2260617.jpg
# Loaded and transformed: 2114112.jpg
# Loaded and transformed: 1455400.jpg
# Loaded and transformed: 0784484.jpg
# Loaded and transformed: 0457841.jpg
# Loaded and transformed: 0859229.jpg
# Loaded and transformed: 1459210.jpg
# Loaded and transformed: 0396507.jpg
# Loaded and transformed: 2239589.jpg
# Loaded and transformed: 1354235.jpg
# Loaded and transformed: 1927186.jpg
# Loaded and transformed: 1109377.jpg
# Loaded and transformed: 1831096.jpg
# Loaded and transformed: 2031384.jpg
# Loaded and transformed: 2169104.jpg
# Loaded and transformed: 1801182.jpg
# Loaded and transformed: 1321494.jpg
# Loaded and transformed: 2031421.jpg
# Loaded and transformed: 0973167.jpg
# Loaded and transformed: 2175263.jpg
# Loaded and transformed: 1400629.jpg
# Loaded and transformed: 1599381.jpg
# Loaded and transformed: 0067618.jpg
# Loaded and transformed: 2209714.jpg
# Loaded and transformed: 0522819.jpg
# Loaded and transformed: 1396941.jpg
# Loaded and transformed: 1645736.jpg
# Loaded and transformed: 2094472.jpg
# Loaded and transformed: 1115400.jpg
# Loaded and transformed: 1921656.jpg
# Loaded and transformed: 2259453.jpg
# Loaded and transformed: 1398987.jpg
# Loaded and transformed: 1999292.jpg
# Loaded and transformed: 1714236.jpg
# Loaded and transformed: 2230427.jpg
# Loaded and transformed: 0676942.jpg
# Loaded and transformed: 0067619.jpg
# Loaded and transformed: 2171602.jpg
# Loaded and transformed: 1650662.jpg
# Loaded and transformed: 1768538.jpg
# Loaded and transformed: 1662015.jpg
# Loaded and transformed: 1222822.jpg
# Loaded and transformed: 1842045.jpg
# Loaded and transformed: 0467798.jpg
# Loaded and transformed: 2158858.jpg
# Loaded and transformed: 2218546.jpg
# Loaded and transformed: 0097111.jpg
# Loaded and transformed: 1163484.jpg
# Loaded and transformed: 0802263.jpg
# Loaded and transformed: 0195013.jpg
# Loaded and transformed: 1826956.jpg
# Loaded and transformed: 1382601.jpg
# Loaded and transformed: 0698787.jpg
# Loaded and transformed: 1538844.jpg
# Loaded and transformed: 0545210.jpg
# Loaded and transformed: 1036863.jpg
# Loaded and transformed: 2182128.jpg
# Loaded and transformed: 1754503.jpg
# Loaded and transformed: 2250798.jpg
# Loaded and transformed: 0225218.jpg
# Loaded and transformed: 0653804.jpg
# Loaded and transformed: 0894188.jpg
# Loaded and transformed: 0522857.jpg
# Loaded and transformed: 0225634.jpg
# Loaded and transformed: 1483195.jpg
# Loaded and transformed: 0422472.jpg
# Loaded and transformed: 1267074.jpg
# Loaded and transformed: 0395652.jpg
# Loaded and transformed: 0075050.jpg
# Loaded and transformed: 2236964.jpg
# Loaded and transformed: 0876440.jpg
# Loaded and transformed: 0498138.jpg
# Loaded and transformed: 2186944.jpg
# Loaded and transformed: 0450740.jpg
# Loaded and transformed: 1333183.jpg
# Loaded and transformed: 0522856.jpg
# Loaded and transformed: 1841489.jpg
# Loaded and transformed: 0894189.jpg
# Loaded and transformed: 0957883.jpg
# Loaded and transformed: 1591976.jpg
# Loaded and transformed: 0527682.jpg
# Loaded and transformed: 2072231.jpg
# Loaded and transformed: 1663379.jpg
# Loaded and transformed: 1192642.jpg
# Loaded and transformed: 2188604.jpg
# Loaded and transformed: 0863885.jpg
# Loaded and transformed: 0740884.jpg
# Loaded and transformed: 0225227.jpg
# Loaded and transformed: 0361471.jpg
# Loaded and transformed: 0701628.jpg
# Loaded and transformed: 0114122.jpg
# Loaded and transformed: 2198761.jpg
# Loaded and transformed: 1776825.jpg
# Loaded and transformed: 2113949.jpg
# Loaded and transformed: 1149871.jpg
# Loaded and transformed: 0198440.jpg
# Loaded and transformed: 0391437.jpg
# Loaded and transformed: 0037512.jpg
# Loaded and transformed: 2156795.jpg
# Loaded and transformed: 0618966.jpg
# Loaded and transformed: 1252026.jpg
# Loaded and transformed: 2099873.jpg
# Loaded and transformed: 1707575.jpg
# Loaded and transformed: 1244687.jpg
# Loaded and transformed: 1129148.jpg
# Loaded and transformed: 1211309.jpg
# Loaded and transformed: 1572350.jpg
# Loaded and transformed: 1771959.jpg
# Loaded and transformed: 0127648.jpg
# Loaded and transformed: 1917223.jpg
# Loaded and transformed: 1375264.jpg
# Loaded and transformed: 1981537.jpg
# Loaded and transformed: 1420016.jpg
# Loaded and transformed: 1946040.jpg
# Loaded and transformed: 1963559.jpg
# Loaded and transformed: 0716437.jpg
# Loaded and transformed: 1555884.jpg
# Loaded and transformed: 2060949.jpg
# Loaded and transformed: 1222076.jpg
# Loaded and transformed: 0974734.jpg
# Loaded and transformed: 0071754.jpg
# Loaded and transformed: 0661734.jpg
# Loaded and transformed: 0923888.jpg
# Loaded and transformed: 1736223.jpg
# Loaded and transformed: 0093510.jpg
# Loaded and transformed: 0381609.jpg
# Loaded and transformed: 1985180.jpg
# Loaded and transformed: 1300002.jpg
# Loaded and transformed: 1886463.jpg
# Loaded and transformed: 1912564.jpg
# Loaded and transformed: 1237650.jpg
# Loaded and transformed: 1879110.jpg
# Loaded and transformed: 2067982.jpg
# Loaded and transformed: 0447762.jpg
# Loaded and transformed: 1425231.jpg
# Loaded and transformed: 2054409.jpg
# Loaded and transformed: 1884738.jpg
# Loaded and transformed: 1898311.jpg
# Loaded and transformed: 1668558.jpg
# Loaded and transformed: 1125617.jpg
# Loaded and transformed: 0755282.jpg
# Loaded and transformed: 1535181.jpg
# Loaded and transformed: 2207610.jpg
# Loaded and transformed: 1362533.jpg
# Loaded and transformed: 2106207.jpg
# Loaded and transformed: 2200427.jpg
# Loaded and transformed: 2094229.jpg
# Loaded and transformed: 0959262.jpg
# Loaded and transformed: 2132361.jpg
# Loaded and transformed: 0939541.jpg
# Loaded and transformed: 1087920.jpg
# Loaded and transformed: 1608084.jpg
# Loaded and transformed: 2236183.jpg
# Loaded and transformed: 0642071.jpg
# Loaded and transformed: 0953559.jpg
# Loaded and transformed: 1019107.jpg
# Loaded and transformed: 1500676.jpg
# Loaded and transformed: 1644649.jpg
# Loaded and transformed: 1857204.jpg
# Loaded and transformed: 1320676.jpg
# Loaded and transformed: 0523219.jpg
# Loaded and transformed: 0740504.jpg
# Loaded and transformed: 0635825.jpg
# Loaded and transformed: 1714240.jpg
# Loaded and transformed: 0192625.jpg
# Loaded and transformed: 1337849.jpg
# Loaded and transformed: 1458030.jpg
# Loaded and transformed: 1876022.jpg
# Loaded and transformed: 1081565.jpg
# Loaded and transformed: 1685202.jpg
# Loaded and transformed: 1736209.jpg
# Loaded and transformed: 1476642.jpg
# Loaded and transformed: 0066410.jpg
# Loaded and transformed: 2195493.jpg
# Loaded and transformed: 1926205.jpg
# Loaded and transformed: 0606801.jpg
# Loaded and transformed: 1594758.jpg
# Loaded and transformed: 1614686.jpg
# Loaded and transformed: 1327939.jpg
# Loaded and transformed: 1231168.jpg
# Loaded and transformed: 1616720.jpg
# Loaded and transformed: 0383395.jpg
# Loaded and transformed: 1362530.jpg
# Loaded and transformed: 1943476.jpg
# Loaded and transformed: 2013386.jpg
# Loaded and transformed: 1388499.jpg
# Loaded and transformed: 0181710.jpg
# Created a tensor of shape: torch.Size([635, 3, 224, 224])

# %%
####################################


#THIS SECOND SECTION WILL IMPORT THE TESTING DATA AND SETUP THE INFORMATION FOR F1 TESTING


####################################

# %%
# File path for the testing data classification file
test_file_path = '/Users/louieburns/Library/CloudStorage/OneDrive-UniversityofLeeds/Year 3/AI and Machine Learning/Term 1/Coursework 1/Actual Coursework/dataoriginal/images_family_test.txt'

# Read and process the testing data file
test_data = []
with open(test_file_path, 'r') as file:
    for i, line in enumerate(file):
        parts = line.strip().split()
        if len(parts) >= 2:  # Ensure there are at least two fields
            number = parts[0]
            classification = ' '.join(parts[1:])  # Combine remaining parts
            test_data.append({"Number": number, "Classification": classification})
        else:
            print(f"Skipping invalid line {i + 1}: {line.strip()}")  # Debugging invalid lines

# Convert to a DataFrame
df_test = pd.DataFrame(test_data)

# Standardise the Classification column
df_test['Classification'] = df_test['Classification'].str.strip()  # Remove extra spaces
df_test['Classification'] = df_test['Classification'].str.title()  # Standardise capitalisation

# Add numeric labels and filter invalid classifications
df_test['Label'] = df_test['Classification'].map(classification_mapping)
df_test = df_test.dropna(subset=['Label']).reset_index(drop=True)  # Remove rows with invalid classifications

# Display the resulting DataFrame
print(df_test)

# Path to the testing images
test_image_folder_path = '/Users/louieburns/Library/CloudStorage/OneDrive-UniversityofLeeds/Year 3/AI and Machine Learning/Term 1/Coursework 1/Actual Coursework/dataoriginal/images'

# Relevant test image codes
relevant_test_codes = set(df_test['Number'])  # Convert to a set for faster lookup

# Initialize a list to hold testing image tensors
test_image_tensors = []

# Define the image transformation (resize and convert to tensor)
transform = transforms.Compose([
    transforms.Resize((224, 224)),  # Resize all images to a fixed size (e.g., 224x224)
    transforms.ToTensor()  # Convert image to PyTorch tensor
])

# Iterate over files in the folder
for image_file in os.listdir(test_image_folder_path):
    # Extract the numeric part of the file name (assuming it's the code)
    code = os.path.splitext(image_file)[0]
    if code in relevant_test_codes and image_file.endswith('.jpg'):
        # Load the image
        image_path = os.path.join(test_image_folder_path, image_file)
        img = Image.open(image_path).convert('RGB')  # Ensure 3 color channels (RGB)
        
        # Transform the image and append to the list
        tensor = transform(img)
        test_image_tensors.append(tensor)
        print(f"Loaded and transformed: {image_file}")

# Stack all tensors into a single tensor
if test_image_tensors:
    test_image_tensor_batch = torch.stack(test_image_tensors)
    print(f"Created a testing tensor of shape: {test_image_tensor_batch.shape}")
else:
    print("No testing images matched the criteria!")

# Example tensor shape: [num_test_images, channels, height, width]
# Out:
#       Number Classification  Label
# 0    0227058     Boeing 737    1.0
# 1    0950275     Boeing 737    1.0
# 2    0114122     Boeing 737    1.0
# 3    1754503     Boeing 737    1.0
# 4    0127648     Boeing 737    1.0
# ..       ...            ...    ...
# 630  0447762     Gulfstream    4.0
# 631  0396507     Gulfstream    4.0
# 632  2030079     Gulfstream    4.0
# 633  1063148     Gulfstream    4.0
# 634  0492487     Gulfstream    4.0
#
# [635 rows x 3 columns]
# Loaded and transformed: 2221342.jpg
# Loaded and transformed: 1548400.jpg
# Loaded and transformed: 1107447.jpg
# Loaded and transformed: 1476061.jpg
# Loaded and transformed: 2227525.jpg
# Loaded and transformed: 1259554.jpg
# Loaded and transformed: 1698699.jpg
# Loaded and transformed: 0218033.jpg
# Loaded and transformed: 1142906.jpg
# Loaded and transformed: 1510253.jpg
# Loaded and transformed: 1119094.jpg
# Loaded and transformed: 1398526.jpg
# Loaded and transformed: 1768807.jpg
# Loaded and transformed: 1508811.jpg
# Loaded and transformed: 2002331.jpg
# Loaded and transformed: 1419049.jpg
# Loaded and transformed: 2190848.jpg
# Loaded and transformed: 1456004.jpg
# Loaded and transformed: 2211444.jpg
# Loaded and transformed: 1336582.jpg
# Loaded and transformed: 1251519.jpg
# Loaded and transformed: 1185069.jpg
# Loaded and transformed: 2228978.jpg
# Loaded and transformed: 1878567.jpg
# Loaded and transformed: 0447745.jpg
# Loaded and transformed: 1272698.jpg
# Loaded and transformed: 1879889.jpg
# Loaded and transformed: 0998786.jpg
# Loaded and transformed: 0918179.jpg
# Loaded and transformed: 0973082.jpg
# Loaded and transformed: 1940832.jpg
# Loaded and transformed: 1876402.jpg
# Loaded and transformed: 0225210.jpg
# Loaded and transformed: 1686317.jpg
# Loaded and transformed: 1403158.jpg
# Loaded and transformed: 0864663.jpg
# Loaded and transformed: 1115297.jpg
# Loaded and transformed: 1663628.jpg
# Loaded and transformed: 0496901.jpg
# Loaded and transformed: 1852007.jpg
# Loaded and transformed: 1676582.jpg
# Loaded and transformed: 0543870.jpg
# Loaded and transformed: 0950275.jpg
# Loaded and transformed: 1934357.jpg
# Loaded and transformed: 1927317.jpg
# Loaded and transformed: 0936133.jpg
# Loaded and transformed: 0944994.jpg
# Loaded and transformed: 0325574.jpg
# Loaded and transformed: 1086833.jpg
# Loaded and transformed: 1545325.jpg
# Loaded and transformed: 0097578.jpg
# Loaded and transformed: 1395798.jpg
# Loaded and transformed: 1078482.jpg
# Loaded and transformed: 1795553.jpg
# Loaded and transformed: 1879121.jpg
# Loaded and transformed: 1550106.jpg
# Loaded and transformed: 2191957.jpg
# Loaded and transformed: 2117298.jpg
# Loaded and transformed: 1085719.jpg
# Loaded and transformed: 1305611.jpg
# Loaded and transformed: 0412223.jpg
# Loaded and transformed: 1885833.jpg
# Loaded and transformed: 1146021.jpg
# Loaded and transformed: 1092270.jpg
# Loaded and transformed: 1358066.jpg
# Loaded and transformed: 1352205.jpg
# Loaded and transformed: 2137161.jpg
# Loaded and transformed: 1950559.jpg
# Loaded and transformed: 1723838.jpg
# Loaded and transformed: 0198104.jpg
# Loaded and transformed: 1295799.jpg
# Loaded and transformed: 2107061.jpg
# Loaded and transformed: 0062679.jpg
# Loaded and transformed: 1922722.jpg
# Loaded and transformed: 1444748.jpg
# Loaded and transformed: 1196360.jpg
# Loaded and transformed: 1967054.jpg
# Loaded and transformed: 1903505.jpg
# Loaded and transformed: 0361109.jpg
# Loaded and transformed: 1066524.jpg
# Loaded and transformed: 1736148.jpg
# Loaded and transformed: 0448049.jpg
# Loaded and transformed: 1418231.jpg
# Loaded and transformed: 1016570.jpg
# Loaded and transformed: 1358664.jpg
# Loaded and transformed: 0497629.jpg
# Loaded and transformed: 0523207.jpg
# Loaded and transformed: 1040656.jpg
# Loaded and transformed: 1279709.jpg
# Loaded and transformed: 1889566.jpg
# Loaded and transformed: 0957899.jpg
# Loaded and transformed: 1133684.jpg
# Loaded and transformed: 1496971.jpg
# Loaded and transformed: 1634373.jpg
# Loaded and transformed: 1261350.jpg
# Loaded and transformed: 0695327.jpg
# Loaded and transformed: 1535566.jpg
# Loaded and transformed: 1461862.jpg
# Loaded and transformed: 2145082.jpg
# Loaded and transformed: 1169979.jpg
# Loaded and transformed: 1597449.jpg
# Loaded and transformed: 1471641.jpg
# Loaded and transformed: 0701751.jpg
# Loaded and transformed: 1356890.jpg
# Loaded and transformed: 1471735.jpg
# Loaded and transformed: 0218801.jpg
# Loaded and transformed: 1771969.jpg
# Loaded and transformed: 0681541.jpg
# Loaded and transformed: 1062970.jpg
# Loaded and transformed: 1971194.jpg
# Loaded and transformed: 2195128.jpg
# Loaded and transformed: 2217839.jpg
# Loaded and transformed: 1088415.jpg
# Loaded and transformed: 0275806.jpg
# Loaded and transformed: 1139751.jpg
# Loaded and transformed: 0923504.jpg
# Loaded and transformed: 0702845.jpg
# Loaded and transformed: 1102089.jpg
# Loaded and transformed: 0668444.jpg
# Loaded and transformed: 2264828.jpg
# Loaded and transformed: 2007890.jpg
# Loaded and transformed: 2018768.jpg
# Loaded and transformed: 1529574.jpg
# Loaded and transformed: 0759316.jpg
# Loaded and transformed: 1088603.jpg
# Loaded and transformed: 1506226.jpg
# Loaded and transformed: 1351643.jpg
# Loaded and transformed: 1682001.jpg
# Loaded and transformed: 0796349.jpg
# Loaded and transformed: 2191945.jpg
# Loaded and transformed: 0972415.jpg
# Loaded and transformed: 0447769.jpg
# Loaded and transformed: 1244306.jpg
# Loaded and transformed: 0482804.jpg
# Loaded and transformed: 0730798.jpg
# Loaded and transformed: 2255571.jpg
# Loaded and transformed: 2135566.jpg
# Loaded and transformed: 1545068.jpg
# Loaded and transformed: 1783685.jpg
# Loaded and transformed: 2263029.jpg
# Loaded and transformed: 1903311.jpg
# Loaded and transformed: 2063913.jpg
# Loaded and transformed: 2038532.jpg
# Loaded and transformed: 1318450.jpg
# Loaded and transformed: 1696061.jpg
# Loaded and transformed: 1602628.jpg
# Loaded and transformed: 1520357.jpg
# Loaded and transformed: 1212753.jpg
# Loaded and transformed: 0713593.jpg
# Loaded and transformed: 2133249.jpg
# Loaded and transformed: 0494478.jpg
# Loaded and transformed: 2207626.jpg
# Loaded and transformed: 0357873.jpg
# Loaded and transformed: 1548404.jpg
# Loaded and transformed: 1139750.jpg
# Loaded and transformed: 1355815.jpg
# Loaded and transformed: 0713752.jpg
# Loaded and transformed: 1312536.jpg
# Loaded and transformed: 2173352.jpg
# Loaded and transformed: 2190977.jpg
# Loaded and transformed: 0880593.jpg
# Loaded and transformed: 1551668.jpg
# Loaded and transformed: 1759298.jpg
# Loaded and transformed: 0649605.jpg
# Loaded and transformed: 1461218.jpg
# Loaded and transformed: 0336540.jpg
# Loaded and transformed: 2067870.jpg
# Loaded and transformed: 1310123.jpg
# Loaded and transformed: 1570498.jpg
# Loaded and transformed: 1647313.jpg
# Loaded and transformed: 0675711.jpg
# Loaded and transformed: 1361876.jpg
# Loaded and transformed: 2128746.jpg
# Loaded and transformed: 1622762.jpg
# Loaded and transformed: 0582863.jpg
# Loaded and transformed: 1659448.jpg
# Loaded and transformed: 1950707.jpg
# Loaded and transformed: 1806227.jpg
# Loaded and transformed: 0104601.jpg
# Loaded and transformed: 1551279.jpg
# Loaded and transformed: 1366856.jpg
# Loaded and transformed: 2137129.jpg
# Loaded and transformed: 1361693.jpg
# Loaded and transformed: 0136472.jpg
# Loaded and transformed: 1335573.jpg
# Loaded and transformed: 1242658.jpg
# Loaded and transformed: 1063148.jpg
# Loaded and transformed: 2194912.jpg
# Loaded and transformed: 0176136.jpg
# Loaded and transformed: 1095184.jpg
# Loaded and transformed: 1529275.jpg
# Loaded and transformed: 0931601.jpg
# Loaded and transformed: 1055149.jpg
# Loaded and transformed: 1458698.jpg
# Loaded and transformed: 0308863.jpg
# Loaded and transformed: 0514744.jpg
# Loaded and transformed: 1807932.jpg
# Loaded and transformed: 0237107.jpg
# Loaded and transformed: 1927638.jpg
# Loaded and transformed: 0133440.jpg
# Loaded and transformed: 2006296.jpg
# Loaded and transformed: 1329158.jpg
# Loaded and transformed: 1364919.jpg
# Loaded and transformed: 1679201.jpg
# Loaded and transformed: 1372809.jpg
# Loaded and transformed: 1047407.jpg
# Loaded and transformed: 2220612.jpg
# Loaded and transformed: 1425707.jpg
# Loaded and transformed: 0257552.jpg
# Loaded and transformed: 1480422.jpg
# Loaded and transformed: 1172324.jpg
# Loaded and transformed: 1860176.jpg
# Loaded and transformed: 0958065.jpg
# Loaded and transformed: 1768872.jpg
# Loaded and transformed: 1838645.jpg
# Loaded and transformed: 2168374.jpg
# Loaded and transformed: 2183458.jpg
# Loaded and transformed: 1526019.jpg
# Loaded and transformed: 1537100.jpg
# Loaded and transformed: 2266336.jpg
# Loaded and transformed: 0741298.jpg
# Loaded and transformed: 1662032.jpg
# Loaded and transformed: 1641833.jpg
# Loaded and transformed: 1882508.jpg
# Loaded and transformed: 0882609.jpg
# Loaded and transformed: 1093247.jpg
# Loaded and transformed: 1224910.jpg
# Loaded and transformed: 1931271.jpg
# Loaded and transformed: 1258401.jpg
# Loaded and transformed: 0074246.jpg
# Loaded and transformed: 2023598.jpg
# Loaded and transformed: 1470663.jpg
# Loaded and transformed: 1758619.jpg
# Loaded and transformed: 0681537.jpg
# Loaded and transformed: 1611219.jpg
# Loaded and transformed: 1018933.jpg
# Loaded and transformed: 1129244.jpg
# Loaded and transformed: 1549035.jpg
# Loaded and transformed: 1055199.jpg
# Loaded and transformed: 1577681.jpg
# Loaded and transformed: 1958758.jpg
# Loaded and transformed: 2234272.jpg
# Loaded and transformed: 2057962.jpg
# Loaded and transformed: 0174054.jpg
# Loaded and transformed: 1762803.jpg
# Loaded and transformed: 1297843.jpg
# Loaded and transformed: 1468400.jpg
# Loaded and transformed: 1659671.jpg
# Loaded and transformed: 1468399.jpg
# Loaded and transformed: 0890396.jpg
# Loaded and transformed: 0218042.jpg
# Loaded and transformed: 1806208.jpg
# Loaded and transformed: 1647665.jpg
# Loaded and transformed: 0492487.jpg
# Loaded and transformed: 2164953.jpg
# Loaded and transformed: 0498140.jpg
# Loaded and transformed: 1080160.jpg
# Loaded and transformed: 0894324.jpg
# Loaded and transformed: 1281985.jpg
# Loaded and transformed: 1921311.jpg
# Loaded and transformed: 2056248.jpg
# Loaded and transformed: 1043473.jpg
# Loaded and transformed: 2160088.jpg
# Loaded and transformed: 1354835.jpg
# Loaded and transformed: 1032301.jpg
# Loaded and transformed: 1398436.jpg
# Loaded and transformed: 0688076.jpg
# Loaded and transformed: 2147231.jpg
# Loaded and transformed: 1953630.jpg
# Loaded and transformed: 0682201.jpg
# Loaded and transformed: 1565290.jpg
# Loaded and transformed: 1790921.jpg
# Loaded and transformed: 0460770.jpg
# Loaded and transformed: 2058107.jpg
# Loaded and transformed: 0795231.jpg
# Loaded and transformed: 2044260.jpg
# Loaded and transformed: 0083150.jpg
# Loaded and transformed: 2238661.jpg
# Loaded and transformed: 0951126.jpg
# Loaded and transformed: 2106086.jpg
# Loaded and transformed: 0880582.jpg
# Loaded and transformed: 2246817.jpg
# Loaded and transformed: 1901160.jpg
# Loaded and transformed: 2211026.jpg
# Loaded and transformed: 0862739.jpg
# Loaded and transformed: 1796759.jpg
# Loaded and transformed: 1077924.jpg
# Loaded and transformed: 0901473.jpg
# Loaded and transformed: 1861737.jpg
# Loaded and transformed: 1769000.jpg
# Loaded and transformed: 2229397.jpg
# Loaded and transformed: 0227058.jpg
# Loaded and transformed: 1565325.jpg
# Loaded and transformed: 0492490.jpg
# Loaded and transformed: 1218624.jpg
# Loaded and transformed: 1429846.jpg
# Loaded and transformed: 1330195.jpg
# Loaded and transformed: 1173014.jpg
# Loaded and transformed: 1288222.jpg
# Loaded and transformed: 1446516.jpg
# Loaded and transformed: 1376842.jpg
# Loaded and transformed: 1069925.jpg
# Loaded and transformed: 1807114.jpg
# Loaded and transformed: 1298958.jpg
# Loaded and transformed: 1966298.jpg
# Loaded and transformed: 1455998.jpg
# Loaded and transformed: 1658586.jpg
# Loaded and transformed: 1899099.jpg
# Loaded and transformed: 1691816.jpg
# Loaded and transformed: 2030079.jpg
# Loaded and transformed: 0072369.jpg
# Loaded and transformed: 1046468.jpg
# Loaded and transformed: 1709124.jpg
# Loaded and transformed: 1591312.jpg
# Loaded and transformed: 1304344.jpg
# Loaded and transformed: 1615914.jpg
# Loaded and transformed: 2245660.jpg
# Loaded and transformed: 1365786.jpg
# Loaded and transformed: 1471543.jpg
# Loaded and transformed: 2190740.jpg
# Loaded and transformed: 0446944.jpg
# Loaded and transformed: 0704268.jpg
# Loaded and transformed: 0764239.jpg
# Loaded and transformed: 1579853.jpg
# Loaded and transformed: 0979665.jpg
# Loaded and transformed: 1340279.jpg
# Loaded and transformed: 1222601.jpg
# Loaded and transformed: 0076843.jpg
# Loaded and transformed: 1143441.jpg
# Loaded and transformed: 1377012.jpg
# Loaded and transformed: 2069707.jpg
# Loaded and transformed: 1423426.jpg
# Loaded and transformed: 1655252.jpg
# Loaded and transformed: 2192006.jpg
# Loaded and transformed: 0699565.jpg
# Loaded and transformed: 2223311.jpg
# Loaded and transformed: 1546282.jpg
# Loaded and transformed: 1244625.jpg
# Loaded and transformed: 1398982.jpg
# Loaded and transformed: 2253635.jpg
# Loaded and transformed: 1813838.jpg
# Loaded and transformed: 2161158.jpg
# Loaded and transformed: 0558343.jpg
# Loaded and transformed: 0305545.jpg
# Loaded and transformed: 1367016.jpg
# Loaded and transformed: 1385093.jpg
# Loaded and transformed: 0147057.jpg
# Loaded and transformed: 0746112.jpg
# Loaded and transformed: 0454592.jpg
# Loaded and transformed: 1810855.jpg
# Loaded and transformed: 1454446.jpg
# Loaded and transformed: 1871273.jpg
# Loaded and transformed: 1636521.jpg
# Loaded and transformed: 1966096.jpg
# Loaded and transformed: 1469738.jpg
# Loaded and transformed: 1110805.jpg
# Loaded and transformed: 1881962.jpg
# Loaded and transformed: 0717995.jpg
# Loaded and transformed: 1842040.jpg
# Loaded and transformed: 0182727.jpg
# Loaded and transformed: 1178011.jpg
# Loaded and transformed: 1891967.jpg
# Loaded and transformed: 1561990.jpg
# Loaded and transformed: 2170860.jpg
# Loaded and transformed: 1113895.jpg
# Loaded and transformed: 1561986.jpg
# Loaded and transformed: 1739566.jpg
# Loaded and transformed: 1363662.jpg
# Loaded and transformed: 1469699.jpg
# Loaded and transformed: 1810937.jpg
# Loaded and transformed: 2229401.jpg
# Loaded and transformed: 0847415.jpg
# Loaded and transformed: 1163792.jpg
# Loaded and transformed: 1393354.jpg
# Loaded and transformed: 0987802.jpg
# Loaded and transformed: 1806210.jpg
# Loaded and transformed: 1713238.jpg
# Loaded and transformed: 1552592.jpg
# Loaded and transformed: 1237623.jpg
# Loaded and transformed: 1169718.jpg
# Loaded and transformed: 1308404.jpg
# Loaded and transformed: 1577934.jpg
# Loaded and transformed: 0770474.jpg
# Loaded and transformed: 0890827.jpg
# Loaded and transformed: 1291783.jpg
# Loaded and transformed: 2033184.jpg
# Loaded and transformed: 0669870.jpg
# Loaded and transformed: 1796970.jpg
# Loaded and transformed: 0962643.jpg
# Loaded and transformed: 0875303.jpg
# Loaded and transformed: 1100234.jpg
# Loaded and transformed: 2180164.jpg
# Loaded and transformed: 1714026.jpg
# Loaded and transformed: 1535044.jpg
# Loaded and transformed: 1619270.jpg
# Loaded and transformed: 1163793.jpg
# Loaded and transformed: 2241970.jpg
# Loaded and transformed: 0259167.jpg
# Loaded and transformed: 1687909.jpg
# Loaded and transformed: 1124590.jpg
# Loaded and transformed: 0218852.jpg
# Loaded and transformed: 0851302.jpg
# Loaded and transformed: 1606542.jpg
# Loaded and transformed: 1935750.jpg
# Loaded and transformed: 0939519.jpg
# Loaded and transformed: 0944257.jpg
# Loaded and transformed: 0361611.jpg
# Loaded and transformed: 1336460.jpg
# Loaded and transformed: 0857549.jpg
# Loaded and transformed: 0944247.jpg
# Loaded and transformed: 1238449.jpg
# Loaded and transformed: 1091663.jpg
# Loaded and transformed: 1586117.jpg
# Loaded and transformed: 1900937.jpg
# Loaded and transformed: 1910729.jpg
# Loaded and transformed: 1363673.jpg
# Loaded and transformed: 0063284.jpg
# Loaded and transformed: 1860580.jpg
# Loaded and transformed: 1268068.jpg
# Loaded and transformed: 0673596.jpg
# Loaded and transformed: 0694480.jpg
# Loaded and transformed: 1008903.jpg
# Loaded and transformed: 2173639.jpg
# Loaded and transformed: 1421021.jpg
# Loaded and transformed: 1110779.jpg
# Loaded and transformed: 0807961.jpg
# Loaded and transformed: 1510217.jpg
# Loaded and transformed: 2134406.jpg
# Loaded and transformed: 1296201.jpg
# Loaded and transformed: 2139678.jpg
# Loaded and transformed: 0522417.jpg
# Loaded and transformed: 1545982.jpg
# Loaded and transformed: 1559373.jpg
# Loaded and transformed: 1559372.jpg
# Loaded and transformed: 0175746.jpg
# Loaded and transformed: 0075752.jpg
# Loaded and transformed: 1351213.jpg
# Loaded and transformed: 1393634.jpg
# Loaded and transformed: 2116329.jpg
# Loaded and transformed: 1788034.jpg
# Loaded and transformed: 2152231.jpg
# Loaded and transformed: 1381998.jpg
# Loaded and transformed: 2126017.jpg
# Loaded and transformed: 2187801.jpg
# Loaded and transformed: 2054442.jpg
# Loaded and transformed: 0965713.jpg
# Loaded and transformed: 2223909.jpg
# Loaded and transformed: 1943358.jpg
# Loaded and transformed: 2260617.jpg
# Loaded and transformed: 2114112.jpg
# Loaded and transformed: 1455400.jpg
# Loaded and transformed: 0784484.jpg
# Loaded and transformed: 0457841.jpg
# Loaded and transformed: 0859229.jpg
# Loaded and transformed: 1459210.jpg
# Loaded and transformed: 0396507.jpg
# Loaded and transformed: 2239589.jpg
# Loaded and transformed: 1354235.jpg
# Loaded and transformed: 1927186.jpg
# Loaded and transformed: 1109377.jpg
# Loaded and transformed: 1831096.jpg
# Loaded and transformed: 2031384.jpg
# Loaded and transformed: 2169104.jpg
# Loaded and transformed: 1801182.jpg
# Loaded and transformed: 1321494.jpg
# Loaded and transformed: 2031421.jpg
# Loaded and transformed: 0973167.jpg
# Loaded and transformed: 2175263.jpg
# Loaded and transformed: 1400629.jpg
# Loaded and transformed: 1599381.jpg
# Loaded and transformed: 0067618.jpg
# Loaded and transformed: 2209714.jpg
# Loaded and transformed: 0522819.jpg
# Loaded and transformed: 1396941.jpg
# Loaded and transformed: 1645736.jpg
# Loaded and transformed: 2094472.jpg
# Loaded and transformed: 1115400.jpg
# Loaded and transformed: 1921656.jpg
# Loaded and transformed: 2259453.jpg
# Loaded and transformed: 1398987.jpg
# Loaded and transformed: 1999292.jpg
# Loaded and transformed: 1714236.jpg
# Loaded and transformed: 2230427.jpg
# Loaded and transformed: 0676942.jpg
# Loaded and transformed: 0067619.jpg
# Loaded and transformed: 2171602.jpg
# Loaded and transformed: 1650662.jpg
# Loaded and transformed: 1768538.jpg
# Loaded and transformed: 1662015.jpg
# Loaded and transformed: 1222822.jpg
# Loaded and transformed: 1842045.jpg
# Loaded and transformed: 0467798.jpg
# Loaded and transformed: 2158858.jpg
# Loaded and transformed: 2218546.jpg
# Loaded and transformed: 0097111.jpg
# Loaded and transformed: 1163484.jpg
# Loaded and transformed: 0802263.jpg
# Loaded and transformed: 0195013.jpg
# Loaded and transformed: 1826956.jpg
# Loaded and transformed: 1382601.jpg
# Loaded and transformed: 0698787.jpg
# Loaded and transformed: 1538844.jpg
# Loaded and transformed: 0545210.jpg
# Loaded and transformed: 1036863.jpg
# Loaded and transformed: 2182128.jpg
# Loaded and transformed: 1754503.jpg
# Loaded and transformed: 2250798.jpg
# Loaded and transformed: 0225218.jpg
# Loaded and transformed: 0653804.jpg
# Loaded and transformed: 0894188.jpg
# Loaded and transformed: 0522857.jpg
# Loaded and transformed: 0225634.jpg
# Loaded and transformed: 1483195.jpg
# Loaded and transformed: 0422472.jpg
# Loaded and transformed: 1267074.jpg
# Loaded and transformed: 0395652.jpg
# Loaded and transformed: 0075050.jpg
# Loaded and transformed: 2236964.jpg
# Loaded and transformed: 0876440.jpg
# Loaded and transformed: 0498138.jpg
# Loaded and transformed: 2186944.jpg
# Loaded and transformed: 0450740.jpg
# Loaded and transformed: 1333183.jpg
# Loaded and transformed: 0522856.jpg
# Loaded and transformed: 1841489.jpg
# Loaded and transformed: 0894189.jpg
# Loaded and transformed: 0957883.jpg
# Loaded and transformed: 1591976.jpg
# Loaded and transformed: 0527682.jpg
# Loaded and transformed: 2072231.jpg
# Loaded and transformed: 1663379.jpg
# Loaded and transformed: 1192642.jpg
# Loaded and transformed: 2188604.jpg
# Loaded and transformed: 0863885.jpg
# Loaded and transformed: 0740884.jpg
# Loaded and transformed: 0225227.jpg
# Loaded and transformed: 0361471.jpg
# Loaded and transformed: 0701628.jpg
# Loaded and transformed: 0114122.jpg
# Loaded and transformed: 2198761.jpg
# Loaded and transformed: 1776825.jpg
# Loaded and transformed: 2113949.jpg
# Loaded and transformed: 1149871.jpg
# Loaded and transformed: 0198440.jpg
# Loaded and transformed: 0391437.jpg
# Loaded and transformed: 0037512.jpg
# Loaded and transformed: 2156795.jpg
# Loaded and transformed: 0618966.jpg
# Loaded and transformed: 1252026.jpg
# Loaded and transformed: 2099873.jpg
# Loaded and transformed: 1707575.jpg
# Loaded and transformed: 1244687.jpg
# Loaded and transformed: 1129148.jpg
# Loaded and transformed: 1211309.jpg
# Loaded and transformed: 1572350.jpg
# Loaded and transformed: 1771959.jpg
# Loaded and transformed: 0127648.jpg
# Loaded and transformed: 1917223.jpg
# Loaded and transformed: 1375264.jpg
# Loaded and transformed: 1981537.jpg
# Loaded and transformed: 1420016.jpg
# Loaded and transformed: 1946040.jpg
# Loaded and transformed: 1963559.jpg
# Loaded and transformed: 0716437.jpg
# Loaded and transformed: 1555884.jpg
# Loaded and transformed: 2060949.jpg
# Loaded and transformed: 1222076.jpg
# Loaded and transformed: 0974734.jpg
# Loaded and transformed: 0071754.jpg
# Loaded and transformed: 0661734.jpg
# Loaded and transformed: 0923888.jpg
# Loaded and transformed: 1736223.jpg
# Loaded and transformed: 0093510.jpg
# Loaded and transformed: 0381609.jpg
# Loaded and transformed: 1985180.jpg
# Loaded and transformed: 1300002.jpg
# Loaded and transformed: 1886463.jpg
# Loaded and transformed: 1912564.jpg
# Loaded and transformed: 1237650.jpg
# Loaded and transformed: 1879110.jpg
# Loaded and transformed: 2067982.jpg
# Loaded and transformed: 0447762.jpg
# Loaded and transformed: 1425231.jpg
# Loaded and transformed: 2054409.jpg
# Loaded and transformed: 1884738.jpg
# Loaded and transformed: 1898311.jpg
# Loaded and transformed: 1668558.jpg
# Loaded and transformed: 1125617.jpg
# Loaded and transformed: 0755282.jpg
# Loaded and transformed: 1535181.jpg
# Loaded and transformed: 2207610.jpg
# Loaded and transformed: 1362533.jpg
# Loaded and transformed: 2106207.jpg
# Loaded and transformed: 2200427.jpg
# Loaded and transformed: 2094229.jpg
# Loaded and transformed: 0959262.jpg
# Loaded and transformed: 2132361.jpg
# Loaded and transformed: 0939541.jpg
# Loaded and transformed: 1087920.jpg
# Loaded and transformed: 1608084.jpg
# Loaded and transformed: 2236183.jpg
# Loaded and transformed: 0642071.jpg
# Loaded and transformed: 0953559.jpg
# Loaded and transformed: 1019107.jpg
# Loaded and transformed: 1500676.jpg
# Loaded and transformed: 1644649.jpg
# Loaded and transformed: 1857204.jpg
# Loaded and transformed: 1320676.jpg
# Loaded and transformed: 0523219.jpg
# Loaded and transformed: 0740504.jpg
# Loaded and transformed: 0635825.jpg
# Loaded and transformed: 1714240.jpg
# Loaded and transformed: 0192625.jpg
# Loaded and transformed: 1337849.jpg
# Loaded and transformed: 1458030.jpg
# Loaded and transformed: 1876022.jpg
# Loaded and transformed: 1081565.jpg
# Loaded and transformed: 1685202.jpg
# Loaded and transformed: 1736209.jpg
# Loaded and transformed: 1476642.jpg
# Loaded and transformed: 0066410.jpg
# Loaded and transformed: 2195493.jpg
# Loaded and transformed: 1926205.jpg
# Loaded and transformed: 0606801.jpg
# Loaded and transformed: 1594758.jpg
# Loaded and transformed: 1614686.jpg
# Loaded and transformed: 1327939.jpg
# Loaded and transformed: 1231168.jpg
# Loaded and transformed: 1616720.jpg
# Loaded and transformed: 0383395.jpg
# Loaded and transformed: 1362530.jpg
# Loaded and transformed: 1943476.jpg
# Loaded and transformed: 2013386.jpg
# Loaded and transformed: 1388499.jpg
# Loaded and transformed: 0181710.jpg
# Created a testing tensor of shape: torch.Size([635, 3, 224, 224])

# %%
####################################


#THIS 3rd SECTION WILL SETUP AND TRAIN THE NEURAL NETWORK

####################################

# %%
import torch.nn as nn
import torch.nn.functional as F
from torch.utils.data import DataLoader, TensorDataset
from sklearn.metrics import f1_score
import matplotlib.pyplot as plt

train_dataset = TensorDataset(
    image_tensor_batch, 
    torch.tensor(df['Label'].values, dtype=torch.long)  # Ensure labels are torch.long
)
train_loader = DataLoader(train_dataset, batch_size=32, shuffle=True)

# Ensure test_image_tensor_batch and df_test['Label'] are defined
test_dataset = TensorDataset(
    test_image_tensor_batch, 
    torch.tensor(df_test['Label'].values, dtype=torch.long)  # Ensure labels are torch.long
)

# Create DataLoader for the testing dataset
test_loader = DataLoader(test_dataset, batch_size=32, shuffle=False)

class CourseworkCNN(nn.Module):
    def __init__(self, num_classes=5):  # Adapt to the number of classes in your dataset
        super(CourseworkCNN, self).__init__()
        
         # First convolutional block
        self.conv1 = nn.Conv2d(3, 32, kernel_size=3, stride=1, padding=1)
        self.bn1 = nn.BatchNorm2d(32)
        self.pool1 = nn.MaxPool2d(kernel_size=2, stride=2)
        
        # Second convolutional block
        self.conv2 = nn.Conv2d(32, 64, kernel_size=3, stride=1, padding=1)
        self.bn2 = nn.BatchNorm2d(64)
        self.pool2 = nn.MaxPool2d(kernel_size=2, stride=2)
        
        # Third convolutional block (optional deeper network)
        self.conv3 = nn.Conv2d(64, 128, kernel_size=3, stride=1, padding=1)
        self.bn3 = nn.BatchNorm2d(128)
        self.pool3 = nn.MaxPool2d(kernel_size=2, stride=2)
        
        # Fully connected layers
        self.fc1 = nn.Linear(128 * 28 * 28, 256)  # Adjust based on image size after convolutions
        self.fc2 = nn.Linear(256, num_classes)
        
    def forward(self, x):
        # Convolutional blocks
        x = self.pool1(F.relu(self.bn1(self.conv1(x))))
        x = self.pool2(F.relu(self.bn2(self.conv2(x))))
        x = self.pool3(F.relu(self.bn3(self.conv3(x))))
        
        # Flatten the tensor
        x = x.view(x.size(0), -1)
        
        # Fully connected layers
        x = F.relu(self.fc1(x))
        x = self.fc2(x)
        
        return x

# Instantiate the CNN model
coursework_cnn = CourseworkCNN(num_classes=28)
print(coursework_cnn)

# Define the loss function and optimizer for the CourseworkCNN
criterion = nn.CrossEntropyLoss()

import torch.optim as optim

# Define your optimizer
optimizer = optim.Adam(coursework_cnn.parameters(), lr=0.001, weight_decay=1e-4)

# Training loop for CourseworkCNN
epochs = 20
metrics = {
    "train_loss": [],
    "test_loss": [],
    "train_acc": [],
    "test_acc": [],
    "f1_score": []
}

coursework_cnn.train()  # Set model to training mode
for epoch in range(epochs):
    running_loss = 0.0
    correct_train = 0
    total_train = 0

    for images, labels in train_loader:  # Use train_loader for training data
        optimizer.zero_grad()  # Zero the parameter gradients
        outputs = coursework_cnn(images)  # Forward pass
        loss = criterion(outputs, labels)  # Compute loss
        loss.backward()  # Backpropagation
        optimizer.step()  # Update weights

        running_loss += loss.item()
        _, preds = torch.max(outputs, 1)
        correct_train += (preds == labels).sum().item()
        total_train += labels.size(0)

    train_accuracy = correct_train / total_train

    # Evaluate on test set
    coursework_cnn.eval()
    test_loss = 0.0
    correct_test = 0
    total_test = 0
    all_true_labels = []
    all_predicted_labels = []
    with torch.no_grad():  # Disable gradient computation
        for images, labels in test_loader:  # Use test_loader for testing data
            outputs = coursework_cnn(images)  # Forward pass
            loss = criterion(outputs, labels)  # Compute loss
            test_loss += loss.item()
            _, preds = torch.max(outputs, 1)  # Get predictions
            correct_test += (preds == labels).sum().item()
            total_test += labels.size(0)

            all_true_labels.extend(labels.cpu().numpy())
            all_predicted_labels.extend(preds.cpu().numpy())

    test_accuracy = correct_test / total_test
    f1 = f1_score(all_true_labels, all_predicted_labels, average='weighted')

    print(f"Epoch [{epoch+1}/{epochs}], Train Loss: {running_loss/len(train_loader):.4f}, Test Loss: {test_loss/len(test_loader):.4f}, Train Acc: {train_accuracy:.4f}, Test Acc: {test_accuracy:.4f}, F1 Score: {f1:.4f}")

    metrics["train_loss"].append(running_loss / len(train_loader))
    metrics["test_loss"].append(test_loss / len(test_loader))
    metrics["train_acc"].append(train_accuracy)
    metrics["test_acc"].append(test_accuracy)
    metrics["f1_score"].append(f1)

    coursework_cnn.train()  # Set model back to training mode after evaluation

# Metrics stored in 'metrics' dictionary for further analysis

# Plotting results
num_epochs = epochs
train_losses = metrics["train_loss"]
test_losses = metrics["test_loss"]
train_accuracies = metrics["train_acc"]
test_accuracies = metrics["test_acc"]
f1_scores = metrics["f1_score"]

# Plot Loss
plt.figure(figsize=(10, 5))
plt.plot(range(1, num_epochs + 1), train_losses, label='Training Loss')
plt.plot(range(1, num_epochs + 1), test_losses, label='Test Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('Training and Test Loss vs Epochs')
plt.legend()
plt.grid(True)
plt.show()

# Plot Accuracy
plt.figure(figsize=(10, 5))
plt.plot(range(1, num_epochs + 1), train_accuracies, label='Training Accuracy')
plt.plot(range(1, num_epochs + 1), test_accuracies, label='Test Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.title('Training and Test Accuracy vs Epochs')
plt.legend()
plt.grid(True)
plt.show()

# Plot F1 Score
plt.figure(figsize=(10, 5))
plt.plot(range(1, num_epochs + 1), f1_scores, label='F1 Score')
plt.xlabel('Epochs')
plt.ylabel('F1 Score')
plt.title('F1 Score vs Epochs')
plt.legend()
plt.grid(True)
plt.show()
# Out:
# CourseworkCNN(
#   (conv1): Conv2d(3, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (bn1): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (pool1): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   (conv2): Conv2d(32, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (pool2): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   (conv3): Conv2d(64, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (bn3): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (pool3): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   (fc1): Linear(in_features=100352, out_features=256, bias=True)
#   (fc2): Linear(in_features=256, out_features=28, bias=True)
# )
# Epoch [1/20], Train Loss: 26.7076, Test Loss: 8.2243, Train Acc: 0.2504, Test Acc: 0.1953, F1 Score: 0.1716
# Epoch [2/20], Train Loss: 7.7657, Test Loss: 4.1923, Train Acc: 0.3087, Test Acc: 0.2079, F1 Score: 0.1289
# Epoch [3/20], Train Loss: 3.4494, Test Loss: 2.8217, Train Acc: 0.3354, Test Acc: 0.4346, F1 Score: 0.3314
# Epoch [4/20], Train Loss: 1.8291, Test Loss: 2.0594, Train Acc: 0.4299, Test Acc: 0.4835, F1 Score: 0.3712
# Epoch [5/20], Train Loss: 1.7922, Test Loss: 1.4725, Train Acc: 0.4740, Test Acc: 0.5654, F1 Score: 0.5127
# Epoch [6/20], Train Loss: 1.4572, Test Loss: 1.0134, Train Acc: 0.5291, Test Acc: 0.6535, F1 Score: 0.6374
# Epoch [7/20], Train Loss: 1.7346, Test Loss: 1.4358, Train Acc: 0.5370, Test Acc: 0.5197, F1 Score: 0.5002
# Epoch [8/20], Train Loss: 1.3155, Test Loss: 1.5834, Train Acc: 0.5890, Test Acc: 0.5512, F1 Score: 0.4588
# Epoch [9/20], Train Loss: 1.1564, Test Loss: 1.2558, Train Acc: 0.6063, Test Acc: 0.6567, F1 Score: 0.6093
# Epoch [10/20], Train Loss: 0.9560, Test Loss: 0.7762, Train Acc: 0.6646, Test Acc: 0.6992, F1 Score: 0.6783
# Epoch [11/20], Train Loss: 0.6621, Test Loss: 0.4404, Train Acc: 0.7496, Test Acc: 0.8551, F1 Score: 0.8522
# Epoch [12/20], Train Loss: 0.5829, Test Loss: 0.5103, Train Acc: 0.7780, Test Acc: 0.7984, F1 Score: 0.8160
# Epoch [13/20], Train Loss: 0.4439, Test Loss: 0.3150, Train Acc: 0.8346, Test Acc: 0.9055, F1 Score: 0.9072
# Epoch [14/20], Train Loss: 0.3645, Test Loss: 0.2432, Train Acc: 0.8787, Test Acc: 0.9606, F1 Score: 0.9606
# Epoch [15/20], Train Loss: 0.2616, Test Loss: 0.2757, Train Acc: 0.9323, Test Acc: 0.9118, F1 Score: 0.9112
# Epoch [16/20], Train Loss: 0.2891, Test Loss: 0.1849, Train Acc: 0.8913, Test Acc: 0.9465, F1 Score: 0.9451
# Epoch [17/20], Train Loss: 0.2231, Test Loss: 0.1607, Train Acc: 0.9323, Test Acc: 0.9732, F1 Score: 0.9733
# Epoch [18/20], Train Loss: 0.1713, Test Loss: 0.1915, Train Acc: 0.9528, Test Acc: 0.9543, F1 Score: 0.9546
# Epoch [19/20], Train Loss: 0.1290, Test Loss: 0.0793, Train Acc: 0.9701, Test Acc: 0.9953, F1 Score: 0.9953
# Epoch [20/20], Train Loss: 0.0972, Test Loss: 0.0617, Train Acc: 0.9890, Test Acc: 0.9984, F1 Score: 0.9984

# %%
####################################


#THIS 4th SECTION COMPLETES AN F1 TEST ON THE TRAINING DATA

####################################

# %%
# Compute F1-score using true and predicted labels from the evaluation loop
average_f1 = f1_score(true_labels, predicted_labels, average='weighted')
print(f"Average F1-Score: {average_f1}")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[12], line 2
#       1 # Compute F1-score using true and predicted labels from the evaluation loop
# ----> 2 average_f1 = f1_score(true_labels, predicted_labels, average='weighted')
#       3 print(f"Average F1-Score: {average_f1}")
#
# NameError: name 'true_labels' is not defined
