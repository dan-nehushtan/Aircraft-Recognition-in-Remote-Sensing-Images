# %%
import os
import time
import torch
from torch import nn, optim
from torch.utils.data import TensorDataset, DataLoader
from torchvision import transforms
from PIL import Image
import matplotlib.pyplot as plt
from collections import Counter
from sklearn.metrics import f1_score

# Define the folder containing the images
image_folder = '/Users/louieburns/Library/CloudStorage/OneDrive-UniversityofLeeds/Year 3/AI and Machine Learning/Term 1/Coursework 1/Actual Coursework/dataoriginal/images'

# Paths to the text files
train_label_file = '/Users/louieburns/Library/CloudStorage/OneDrive-UniversityofLeeds/Year 3/AI and Machine Learning/Term 1/Coursework 1/Actual Coursework/dataoriginal/images_family_train.txt'
test_label_file = '/Users/louieburns/Library/CloudStorage/OneDrive-UniversityofLeeds/Year 3/AI and Machine Learning/Term 1/Coursework 1/Actual Coursework/dataoriginal/images_family_test.txt'
val_label_file = '/Users/louieburns/Library/CloudStorage/OneDrive-UniversityofLeeds/Year 3/AI and Machine Learning/Term 1/Coursework 1/Actual Coursework/dataoriginal/images_family_trainval.txt'

# Define label mapping
label_mapping = {
    "Boeing 707": 0,
    "Boeing 727": 1,
    "Boeing 737": 2,
    "Boeing 747": 3,
    "Boeing 757": 4,
    "Boeing 767": 5,
    "Boeing 777": 6,
    "A300": 7,
    "A310": 8,
    "A320": 9,
    "A330": 10,
    "A340": 11,
    "A380": 12,
    "ATR-42": 13,
    "ATR-72": 14,
    "An-12": 15,
    "BAE 146": 16,
    "BAE-125": 17,
    "Beechcraft 1900": 18,
    "Boeing 717": 19,
    "C-130": 20,
    "C-47": 21,
    "CRJ-200": 22,
    "CRJ-700": 23,
    "Cessna 172": 24,
    "Cessna 208": 25,
    "Cessna Citation": 26,
    "Challenger 600": 27,
    "DC-10": 28,
    "DC-3": 29,
    "DC-6": 30,
    "DC-8": 31,
    "DC-9": 32,
    "DH-82": 33,
    "DHC-1": 34,
    "DHC-6": 35,
    "Dash 8": 36,
    "DR-400": 37,
    "Dornier 328": 38,
    "Embraer E-Jet": 39,
    "EMB-120": 40,
    "Embraer ERJ 145": 41,
    "Embraer Legacy 600": 42,
    "Eurofighter Typhoon": 43,
    "F-16": 44,
    "F/A-18": 45,
    "Falcon 2000": 46,
    "Falcon 900": 47,
    "Fokker 100": 48,
    "Fokker 50": 49,
    "Fokker 70": 50,
    "Global Express": 51,
    "Gulfstream": 52,
    "Hawk T1": 53,
    "Il-76": 54,
    "L-1011": 55,
    "MD-11": 56,
    "MD-80": 57,
    "MD-90": 58,
    "Metroliner": 59,
    "King Air": 60,
    "PA-28": 61,
    "SR-20": 62,
    "Saab 2000": 63,
    "Saab 340": 64,
    "Spitfire": 65,
    "Tornado": 66,
    "Tu-134": 67,
    "Tu-154": 68,
    "Yak-42": 69
}

# Define transformations for image processing
transform = transforms.Compose([
    transforms.Resize((128, 128)),  # Resize to 128x128
    transforms.RandomHorizontalFlip(),  # Apply random horizontal flip
    transforms.RandomRotation(15),  # Random rotation
    transforms.ColorJitter(brightness=0.2, contrast=0.2, saturation=0.2, hue=0.1),  # Apply color jitter
    transforms.ToTensor(),          # Convert to tensor
    transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])  # Normalize
])

def count_labels(label_file):
    label_counts = Counter()
    with open(label_file, "r") as f:
        for line in f:
            parts = line.strip().split(maxsplit=1)
            if len(parts) == 2:
                _, label = parts
                label_counts[label] += 1
    return label_counts

def filter_data(label_file, top_labels):
    image_data = []
    labels = []

    with open(label_file, "r") as f:
        for line in f:
            parts = line.strip().split(maxsplit=1)
            if len(parts) != 2:
                continue  # Skip malformed lines
            filename, label = parts
            if label in top_labels:
                image_path = os.path.join(image_folder, filename + ".jpg")
                try:
                    if os.path.exists(image_path):
                        image = Image.open(image_path).convert("RGB")
                        image_tensor = transform(image)
                        image_data.append(image_tensor)
                        labels.append(top_labels[label])
                except Exception as e:
                    print(f"Error processing {image_path}: {e}")

    # Convert lists to PyTorch tensors
    image_tensor = torch.stack(image_data)
    label_tensor = torch.tensor(labels, dtype=torch.long)

    return image_tensor, label_tensor

# Count and select top 5 labels
label_counts = count_labels(train_label_file)
top_5_labels = dict(label_counts.most_common(5))
print("Top 5 Labels:", top_5_labels)

# Remap top labels to sequential indices
label_mapping_top5 = {label: idx for idx, (label, _) in enumerate(top_5_labels.items())}

# Process training, validation, and test data for top 5 labels
train_image_tensor, train_label_tensor = filter_data(train_label_file, label_mapping_top5)
val_image_tensor, val_label_tensor = filter_data(val_label_file, label_mapping_top5)
test_image_tensor, test_label_tensor = filter_data(test_label_file, label_mapping_top5)

# Create TensorDatasets
train_dataset = TensorDataset(train_image_tensor, train_label_tensor)
val_dataset = TensorDataset(val_image_tensor, val_label_tensor)
test_dataset = TensorDataset(test_image_tensor, test_label_tensor)

# Example usage of DataLoader
batch_size = 64
train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)
val_loader = DataLoader(val_dataset, batch_size=batch_size, shuffle=False)
test_loader = DataLoader(test_dataset, batch_size=batch_size, shuffle=False)
print("DataLoaders for top 5 labels created successfully.")

# Define the CNN model
class EnhancedCNN(nn.Module):
    def __init__(self):
        super(EnhancedCNN, self).__init__()
        self.conv1 = nn.Conv2d(3, 64, kernel_size=3, padding=1)
        self.conv2 = nn.Conv2d(64, 128, kernel_size=3, padding=1)
        self.conv3 = nn.Conv2d(128, 256, kernel_size=3, padding=1)
        self.pool = nn.MaxPool2d(2, 2)
        self.dropout = nn.Dropout(0.4)
        self.fc1 = nn.Linear(256 * 16 * 16, 512)
        self.fc2 = nn.Linear(512, 256)
        self.fc3 = nn.Linear(256, len(top_5_labels))
        self.relu = nn.ReLU()

    def forward(self, x):
        x = self.pool(self.relu(self.conv1(x)))
        x = self.pool(self.relu(self.conv2(x)))
        x = self.pool(self.relu(self.conv3(x)))
        x = x.view(-1, 256 * 16 * 16)
        x = self.dropout(self.relu(self.fc1(x)))
        x = self.dropout(self.relu(self.fc2(x)))
        x = self.fc3(x)
        return x

# Instantiate the enhanced model
model = EnhancedCNN()

# Define loss function and optimizer
criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(model.parameters(), lr=0.0005)  # Reduced learning rate for finer adjustments

# Add learning rate scheduler
from torch.optim.lr_scheduler import StepLR
scheduler = StepLR(optimizer, step_size=10, gamma=0.1)  # Decay learning rate by 0.1 every 10 epochs

# Training loop with validation and F1 score calculation
num_epochs = 50
history = {'train_loss': [], 'test_loss': [], 'train_acc': [], 'test_acc': []}
total_start_time = time.time()  # Start timing the entire process

for epoch in range(num_epochs):
    epoch_start_time = time.time()  # Start timing the epoch

    model.train()
    running_loss = 0.0
    correct_train = 0
    total_train = 0
    for images, labels in train_loader:
        optimizer.zero_grad()
        outputs = model(images)
        loss = criterion(outputs, labels)
        loss.backward()
        optimizer.step()
        running_loss += loss.item()

        _, predicted = torch.max(outputs, 1)
        total_train += labels.size(0)
        correct_train += (predicted == labels).sum().item()

    train_accuracy = correct_train / total_train
    history['train_loss'].append(running_loss / len(train_loader))
    history['train_acc'].append(train_accuracy)

    # Update scheduler
    scheduler.step()

    # Evaluate on test data
    model.eval()
    test_loss = 0.0
    correct_test = 0
    total_test = 0
    true_labels = []
    predicted_labels = []
    with torch.no_grad():
        for images, labels in test_loader:
            outputs = model(images)
            loss = criterion(outputs, labels)
            test_loss += loss.item()
            _, predicted = torch.max(outputs, 1)
            total_test += labels.size(0)
            correct_test += (predicted == labels).sum().item()

            # Collect true and predicted labels for F1-score calculation
            true_labels.extend(labels.cpu().numpy())
            predicted_labels.extend(predicted.cpu().numpy())

    test_accuracy = correct_test / total_test
    history['test_loss'].append(test_loss / len(test_loader))
    history['test_acc'].append(test_accuracy)

    # Calculate F1 score
    average_f1 = f1_score(true_labels, predicted_labels, average='weighted')

    epoch_duration = time.time() - epoch_start_time  # Calculate epoch duration
    remaining_time = epoch_duration * (num_epochs - epoch - 1)  # Estimate remaining time
    print(f"Epoch [{epoch+1}/{num_epochs}], Train Loss: {running_loss/len(train_loader):.4f}, Test Loss: {test_loss/len(test_loader):.4f}, Train Acc: {train_accuracy:.4f}, Test Acc: {test_accuracy:.4f}, F1 Score: {average_f1:.4f}, Time Remaining: {remaining_time/60:.4f} mins")

# Calculate total training time
total_time = time.time() - total_start_time
print(f"Total training time: {total_time/60:.2f} minutes")

# Plotting the results
epochs = range(1, num_epochs + 1)

# Plot Loss
plt.figure(figsize=(10, 5))
plt.plot(epochs, history['train_loss'], label='Training Loss')
plt.plot(epochs, history['test_loss'], label='Test Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('Training and Test Loss vs Epochs')
plt.legend()
plt.grid(True)
plt.show()

# Plot Accuracy
plt.figure(figsize=(10, 5))
plt.plot(epochs, history['train_acc'], label='Training Accuracy')
plt.plot(epochs, history['test_acc'], label='Test Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.title('Training and Test Accuracy vs Epochs')
plt.legend()
plt.grid(True)
plt.show()
# Out:
# Top 5 Labels: {'Boeing 737': 267, 'Boeing 747': 133, 'A320': 133, 'A340': 133, 'Boeing 767': 100}
# DataLoaders for top 5 labels created successfully.
# Epoch [1/50], Train Loss: 1.5814, Test Loss: 1.5629, Train Acc: 0.3238, Test Acc: 0.3477, F1 Score: 0.1794, Time Remaining: 25.3805 mins
# Epoch [2/50], Train Loss: 1.5576, Test Loss: 1.5524, Train Acc: 0.3551, Test Acc: 0.3477, F1 Score: 0.1794, Time Remaining: 24.8281 mins
# Epoch [3/50], Train Loss: 1.5395, Test Loss: 1.5339, Train Acc: 0.3486, Test Acc: 0.3477, F1 Score: 0.1794, Time Remaining: 25.7284 mins
# Epoch [4/50], Train Loss: 1.5182, Test Loss: 1.5422, Train Acc: 0.3525, Test Acc: 0.3438, F1 Score: 0.1891, Time Remaining: 24.2912 mins
# Epoch [5/50], Train Loss: 1.4990, Test Loss: 1.5159, Train Acc: 0.3603, Test Acc: 0.3581, F1 Score: 0.2534, Time Remaining: 24.8041 mins
# Epoch [6/50], Train Loss: 1.4285, Test Loss: 1.4934, Train Acc: 0.3877, Test Acc: 0.3711, F1 Score: 0.2825, Time Remaining: 23.7005 mins
# Epoch [7/50], Train Loss: 1.3456, Test Loss: 1.4933, Train Acc: 0.4543, Test Acc: 0.3672, F1 Score: 0.3117, Time Remaining: 25.3943 mins
# Epoch [8/50], Train Loss: 1.2622, Test Loss: 1.4855, Train Acc: 0.5013, Test Acc: 0.3659, F1 Score: 0.2958, Time Remaining: 24.7753 mins
# Epoch [9/50], Train Loss: 1.1364, Test Loss: 1.5862, Train Acc: 0.5601, Test Acc: 0.3815, F1 Score: 0.3417, Time Remaining: 24.7073 mins
# Epoch [10/50], Train Loss: 0.9592, Test Loss: 1.5235, Train Acc: 0.6410, Test Acc: 0.3815, F1 Score: 0.3766, Time Remaining: 22.0757 mins
# Epoch [11/50], Train Loss: 0.8033, Test Loss: 1.6034, Train Acc: 0.7376, Test Acc: 0.3828, F1 Score: 0.3564, Time Remaining: 21.1423 mins
# Epoch [12/50], Train Loss: 0.7155, Test Loss: 1.6826, Train Acc: 0.7285, Test Acc: 0.3815, F1 Score: 0.3683, Time Remaining: 19.8122 mins
# Epoch [13/50], Train Loss: 0.6630, Test Loss: 1.7069, Train Acc: 0.7676, Test Acc: 0.3867, F1 Score: 0.3733, Time Remaining: 22.5133 mins
# Epoch [14/50], Train Loss: 0.6086, Test Loss: 1.7323, Train Acc: 0.7781, Test Acc: 0.3867, F1 Score: 0.3711, Time Remaining: 24.5701 mins
# Epoch [15/50], Train Loss: 0.6077, Test Loss: 1.7450, Train Acc: 0.7807, Test Acc: 0.3815, F1 Score: 0.3677, Time Remaining: 23.0961 mins
# Epoch [16/50], Train Loss: 0.5467, Test Loss: 1.7735, Train Acc: 0.8159, Test Acc: 0.3932, F1 Score: 0.3827, Time Remaining: 26.3489 mins
# Epoch [17/50], Train Loss: 0.4905, Test Loss: 1.8642, Train Acc: 0.8433, Test Acc: 0.4049, F1 Score: 0.3844, Time Remaining: 26.3193 mins
# Epoch [18/50], Train Loss: 0.4517, Test Loss: 1.8599, Train Acc: 0.8551, Test Acc: 0.3867, F1 Score: 0.3794, Time Remaining: 25.0432 mins
# Epoch [19/50], Train Loss: 0.4083, Test Loss: 1.9494, Train Acc: 0.8734, Test Acc: 0.3893, F1 Score: 0.3743, Time Remaining: 18.7042 mins
# Epoch [20/50], Train Loss: 0.3963, Test Loss: 1.9189, Train Acc: 0.8681, Test Acc: 0.3984, F1 Score: 0.3899, Time Remaining: 15.7446 mins
# Epoch [21/50], Train Loss: 0.3885, Test Loss: 1.9218, Train Acc: 0.8786, Test Acc: 0.3984, F1 Score: 0.3893, Time Remaining: 15.0889 mins
# Epoch [22/50], Train Loss: 0.3812, Test Loss: 1.9260, Train Acc: 0.8812, Test Acc: 0.3984, F1 Score: 0.3882, Time Remaining: 14.9079 mins
# Epoch [23/50], Train Loss: 0.3671, Test Loss: 1.9349, Train Acc: 0.8916, Test Acc: 0.3997, F1 Score: 0.3888, Time Remaining: 14.2935 mins
# Epoch [24/50], Train Loss: 0.3817, Test Loss: 1.9372, Train Acc: 0.8747, Test Acc: 0.4036, F1 Score: 0.3930, Time Remaining: 13.5879 mins
# Epoch [25/50], Train Loss: 0.3619, Test Loss: 1.9391, Train Acc: 0.8851, Test Acc: 0.4062, F1 Score: 0.3955, Time Remaining: 13.2774 mins
# Epoch [26/50], Train Loss: 0.3491, Test Loss: 1.9429, Train Acc: 0.8969, Test Acc: 0.4023, F1 Score: 0.3922, Time Remaining: 12.8937 mins
# Epoch [27/50], Train Loss: 0.3607, Test Loss: 1.9530, Train Acc: 0.8773, Test Acc: 0.3997, F1 Score: 0.3879, Time Remaining: 11.8342 mins
# Epoch [28/50], Train Loss: 0.3355, Test Loss: 1.9572, Train Acc: 0.9060, Test Acc: 0.3984, F1 Score: 0.3876, Time Remaining: 11.3839 mins
# Epoch [29/50], Train Loss: 0.3551, Test Loss: 1.9632, Train Acc: 0.8890, Test Acc: 0.3997, F1 Score: 0.3887, Time Remaining: 10.8616 mins
# Epoch [30/50], Train Loss: 0.3345, Test Loss: 1.9675, Train Acc: 0.8943, Test Acc: 0.3997, F1 Score: 0.3882, Time Remaining: 11.3094 mins
# Epoch [31/50], Train Loss: 0.3362, Test Loss: 1.9682, Train Acc: 0.8969, Test Acc: 0.3997, F1 Score: 0.3881, Time Remaining: 15.6965 mins
# Epoch [32/50], Train Loss: 0.3448, Test Loss: 1.9692, Train Acc: 0.9086, Test Acc: 0.3984, F1 Score: 0.3866, Time Remaining: 14.4104 mins
# Epoch [33/50], Train Loss: 0.3420, Test Loss: 1.9697, Train Acc: 0.9047, Test Acc: 0.3984, F1 Score: 0.3869, Time Remaining: 11.1173 mins
# Epoch [34/50], Train Loss: 0.3433, Test Loss: 1.9697, Train Acc: 0.8969, Test Acc: 0.3971, F1 Score: 0.3856, Time Remaining: 9.2122 mins
# Epoch [35/50], Train Loss: 0.3474, Test Loss: 1.9705, Train Acc: 0.8982, Test Acc: 0.3997, F1 Score: 0.3881, Time Remaining: 8.1280 mins
# Epoch [36/50], Train Loss: 0.3337, Test Loss: 1.9716, Train Acc: 0.9021, Test Acc: 0.3997, F1 Score: 0.3881, Time Remaining: 7.9478 mins
# Epoch [37/50], Train Loss: 0.3387, Test Loss: 1.9723, Train Acc: 0.9008, Test Acc: 0.4010, F1 Score: 0.3891, Time Remaining: 7.4790 mins
# Epoch [38/50], Train Loss: 0.3456, Test Loss: 1.9727, Train Acc: 0.8956, Test Acc: 0.4010, F1 Score: 0.3892, Time Remaining: 6.9234 mins
# Epoch [39/50], Train Loss: 0.3352, Test Loss: 1.9737, Train Acc: 0.9034, Test Acc: 0.3997, F1 Score: 0.3880, Time Remaining: 5.8691 mins
# Epoch [40/50], Train Loss: 0.3520, Test Loss: 1.9737, Train Acc: 0.8877, Test Acc: 0.3997, F1 Score: 0.3880, Time Remaining: 5.2365 mins
# Epoch [41/50], Train Loss: 0.3219, Test Loss: 1.9737, Train Acc: 0.9099, Test Acc: 0.3997, F1 Score: 0.3880, Time Remaining: 4.7237 mins
# Epoch [42/50], Train Loss: 0.3544, Test Loss: 1.9738, Train Acc: 0.8890, Test Acc: 0.3997, F1 Score: 0.3880, Time Remaining: 4.4139 mins
# Epoch [43/50], Train Loss: 0.3360, Test Loss: 1.9738, Train Acc: 0.8956, Test Acc: 0.3997, F1 Score: 0.3880, Time Remaining: 3.9082 mins
# Epoch [44/50], Train Loss: 0.3401, Test Loss: 1.9738, Train Acc: 0.8956, Test Acc: 0.3997, F1 Score: 0.3880, Time Remaining: 3.2286 mins
# Epoch [45/50], Train Loss: 0.3482, Test Loss: 1.9738, Train Acc: 0.8812, Test Acc: 0.3997, F1 Score: 0.3880, Time Remaining: 2.6218 mins
# Epoch [46/50], Train Loss: 0.3388, Test Loss: 1.9738, Train Acc: 0.8930, Test Acc: 0.4010, F1 Score: 0.3892, Time Remaining: 2.1111 mins
# Epoch [47/50], Train Loss: 0.3314, Test Loss: 1.9738, Train Acc: 0.9021, Test Acc: 0.4010, F1 Score: 0.3892, Time Remaining: 1.5814 mins
# Epoch [48/50], Train Loss: 0.3450, Test Loss: 1.9739, Train Acc: 0.8916, Test Acc: 0.4010, F1 Score: 0.3892, Time Remaining: 1.0479 mins
# Epoch [49/50], Train Loss: 0.3434, Test Loss: 1.9739, Train Acc: 0.8969, Test Acc: 0.4010, F1 Score: 0.3892, Time Remaining: 0.5444 mins
# Epoch [50/50], Train Loss: 0.3454, Test Loss: 1.9740, Train Acc: 0.8956, Test Acc: 0.4010, F1 Score: 0.3892, Time Remaining: 0.0000 mins
# Total training time: 28.86 minutes
