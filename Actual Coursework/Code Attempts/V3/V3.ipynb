# %%
####################################


#THIS FIRST SECTION WILL IMPORT THE TRAINING DATA AND SETUP THE INFORMATION FOR TRAINING


####################################

# %%
#import libraries you used 
import os
import pandas as pd
import zipfile
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
import torchvision
import tarfile
from PIL import Image
from torchvision.datasets.utils import download_url
from torch.utils.data import random_split
from torchvision import transforms
import shutil
from sklearn.metrics import f1_score


## Import the data into the document
image_dir = '/Users/louieburns/Library/CloudStorage/OneDrive-UniversityofLeeds/Year 3/AI and Machine Learning/Term 1/Coursework 1/Actual Coursework/dataoriginal/images'
image_files = [f for f in os.listdir(image_dir) if f.endswith('.jpg')]


## CREATE A FILE WITH THE DESIRED IMAGES ONLY

# Define the classifications to filter and their numeric mappings
classification_mapping = {
    "Boeing 707": 0,
    "Boeing 747": 1,
    "A310": 2,
    "Beechcraft 1900": 3,
    "Gulfstream": 4
}

# Define the file path
file_path = 'images_family_train.txt'
# Read the file and handle inconsistent line structures
data = []
with open(file_path, 'r') as file:
    for i, line in enumerate(file):
        parts = line.strip().split()
        if len(parts) >= 2:  # Ensure at least two fields exist
            number = parts[0]
            classification = ' '.join(parts[1:])  # Combine remaining parts
            data.append({"Number": number, "Classification": classification})
        else:
            print(f"Skipping invalid line {i + 1}: {line.strip()}")  # Debugging invalid lines

# Convert to a DataFrame
df = pd.DataFrame(data)

# Standardise the Classification column
df['Classification'] = df['Classification'].str.strip()  # Remove extra spaces
df['Classification'] = df['Classification'].str.title()  # Standardise capitalisation

# Add numeric labels and filter invalid classifications
df['Label'] = df['Classification'].map(classification_mapping)
df = df.dropna(subset=['Label']).reset_index(drop=True)  # Remove rows with invalid classifications

# Display the resulting DataFrame
print(df)

from collections import Counter

# Read the file and collect classifications
classifications = []
with open(file_path, 'r') as file:
    for line in file:
        parts = line.strip().split()
        if len(parts) >= 2:  # Ensure there are at least two fields
            classification = ' '.join(parts[1:]).strip()  # Combine fields after the first
            classifications.append(classification)

# Count the occurrences of each classification
classification_counts = Counter(classifications)

# Display the results
print("Classification Counts:")
for classification, count in classification_counts.items():
    print(f"{classification}: {count}")

# Count the occurrences of each classification in the filtered DataFrame
filtered_classification_counts = df['Classification'].value_counts()

# Display the results
print("Filtered Classification Counts:")
print(filtered_classification_counts)




## Create a folder with only the photos to keep

# Path to your folder containing images
image_folder_path = '/Users/louieburns/Library/CloudStorage/OneDrive-UniversityofLeeds/Year 3/AI and Machine Learning/Term 1/Coursework 1/Actual Coursework/dataoriginal/images'


relevant_codes = set(df['Number'])  # Convert to a set for faster lookup

# Initialize a list to hold image tensors
image_tensors = []

# Define the image transformation (resize and convert to tensor)
transform = transforms.Compose([
    transforms.Resize((224, 224)),  # Resize all images to a fixed size (e.g., 224x224)
    transforms.ToTensor()  # Convert image to PyTorch tensor
])

# Iterate over files in the folder
for image_file in os.listdir(image_folder_path):
    # Extract the numeric part of the file name (assuming it's the code)
    code = os.path.splitext(image_file)[0]
    if code in relevant_codes and image_file.endswith('.jpg'):
        # Load the image
        image_path = os.path.join(image_folder_path, image_file)
        img = Image.open(image_path).convert('RGB')  # Ensure 3 color channels (RGB)
        
        # Transform the image and append to the list
        tensor = transform(img)
        image_tensors.append(tensor)
        print(f"Loaded and transformed: {image_file}")

# Stack all tensors into a single tensor
if image_tensors:
    image_tensor_batch = torch.stack(image_tensors)
    print(f"Created a tensor of shape: {image_tensor_batch.shape}")
else:
    print("No images matched the criteria!")

# Example tensor shape: [num_images, channels, height, width]
# Out:
#       Number Classification  Label
# 0    1025794     Boeing 707    0.0
# 1    1340192     Boeing 707    0.0
# 2    0056978     Boeing 707    0.0
# 3    0698580     Boeing 707    0.0
# 4    0450014     Boeing 707    0.0
# ..       ...            ...    ...
# 295  1857543     Gulfstream    4.0
# 296  0517785     Gulfstream    4.0
# 297  1311419     Gulfstream    4.0
# 298  2106202     Gulfstream    4.0
# 299  0497885     Gulfstream    4.0
#
# [300 rows x 3 columns]
# Classification Counts:
# Boeing 707: 34
# Boeing 727: 33
# Boeing 737: 267
# Boeing 747: 133
# Boeing 757: 67
# Boeing 767: 100
# Boeing 777: 66
# A300: 34
# A310: 33
# A320: 133
# A330: 67
# A340: 133
# A380: 34
# ATR-42: 33
# ATR-72: 33
# An-12: 34
# BAE 146: 66
# BAE-125: 34
# Beechcraft 1900: 33
# Boeing 717: 33
# C-130: 34
# C-47: 33
# CRJ-200: 33
# CRJ-700: 67
# Cessna 172: 33
# Cessna 208: 34
# Cessna Citation: 66
# Challenger 600: 34
# DC-10: 33
# DC-3: 33
# DC-6: 34
# DC-8: 33
# DC-9: 33
# DH-82: 34
# DHC-1: 33
# DHC-6: 33
# Dash 8: 67
# DR-400: 33
# Dornier 328: 34
# Embraer E-Jet: 100
# EMB-120: 33
# Embraer ERJ 145: 67
# Embraer Legacy 600: 33
# Eurofighter Typhoon: 33
# F-16: 34
# F/A-18: 33
# Falcon 2000: 33
# Falcon 900: 34
# Fokker 100: 33
# Fokker 50: 33
# Fokker 70: 34
# Global Express: 33
# Gulfstream: 67
# Hawk T1: 33
# Il-76: 33
# L-1011: 34
# MD-11: 33
# MD-80: 67
# MD-90: 33
# Metroliner: 33
# King Air: 34
# PA-28: 33
# SR-20: 33
# Saab 2000: 34
# Saab 340: 33
# Spitfire: 33
# Tornado: 34
# Tu-134: 33
# Tu-154: 33
# Yak-42: 34
# Filtered Classification Counts:
# Classification
# Boeing 747         133
# Gulfstream          67
# Boeing 707          34
# A310                33
# Beechcraft 1900     33
# Name: count, dtype: int64
# Loaded and transformed: 0894208.jpg
# Loaded and transformed: 0181735.jpg
# Loaded and transformed: 0447803.jpg
# Loaded and transformed: 1707740.jpg
# Loaded and transformed: 0182189.jpg
# Loaded and transformed: 0869742.jpg
# Loaded and transformed: 0147028.jpg
# Loaded and transformed: 0535113.jpg
# Loaded and transformed: 0098489.jpg
# Loaded and transformed: 1514578.jpg
# Loaded and transformed: 0868105.jpg
# Loaded and transformed: 2222716.jpg
# Loaded and transformed: 1100739.jpg
# Loaded and transformed: 1908679.jpg
# Loaded and transformed: 0179070.jpg
# Loaded and transformed: 1256464.jpg
# Loaded and transformed: 1376991.jpg
# Loaded and transformed: 0923502.jpg
# Loaded and transformed: 1319365.jpg
# Loaded and transformed: 0072480.jpg
# Loaded and transformed: 1356102.jpg
# Loaded and transformed: 1052486.jpg
# Loaded and transformed: 1251094.jpg
# Loaded and transformed: 2137160.jpg
# Loaded and transformed: 2197895.jpg
# Loaded and transformed: 0151661.jpg
# Loaded and transformed: 0356149.jpg
# Loaded and transformed: 0442373.jpg
# Loaded and transformed: 0894380.jpg
# Loaded and transformed: 1621237.jpg
# Loaded and transformed: 1098953.jpg
# Loaded and transformed: 1365495.jpg
# Loaded and transformed: 0744234.jpg
# Loaded and transformed: 0487370.jpg
# Loaded and transformed: 1259556.jpg
# Loaded and transformed: 1068733.jpg
# Loaded and transformed: 0497639.jpg
# Loaded and transformed: 1099245.jpg
# Loaded and transformed: 1325476.jpg
# Loaded and transformed: 0851156.jpg
# Loaded and transformed: 1283510.jpg
# Loaded and transformed: 0487374.jpg
# Loaded and transformed: 1113385.jpg
# Loaded and transformed: 1605637.jpg
# Loaded and transformed: 1025794.jpg
# Loaded and transformed: 0368505.jpg
# Loaded and transformed: 1447127.jpg
# Loaded and transformed: 1548200.jpg
# Loaded and transformed: 0169310.jpg
# Loaded and transformed: 0450014.jpg
# Loaded and transformed: 2084806.jpg
# Loaded and transformed: 0853397.jpg
# Loaded and transformed: 1088007.jpg
# Loaded and transformed: 0765599.jpg
# Loaded and transformed: 1857541.jpg
# Loaded and transformed: 2088351.jpg
# Loaded and transformed: 0650456.jpg
# Loaded and transformed: 0864665.jpg
# Loaded and transformed: 1340228.jpg
# Loaded and transformed: 1700389.jpg
# Loaded and transformed: 0365342.jpg
# Loaded and transformed: 1541386.jpg
# Loaded and transformed: 0684605.jpg
# Loaded and transformed: 0447806.jpg
# Loaded and transformed: 0139685.jpg
# Loaded and transformed: 2245399.jpg
# Loaded and transformed: 1358854.jpg
# Loaded and transformed: 0843964.jpg
# Loaded and transformed: 1857543.jpg
# Loaded and transformed: 0843145.jpg
# Loaded and transformed: 2175624.jpg
# Loaded and transformed: 0729223.jpg
# Loaded and transformed: 0147038.jpg
# Loaded and transformed: 1376174.jpg
# Loaded and transformed: 0913940.jpg
# Loaded and transformed: 1347626.jpg
# Loaded and transformed: 0781152.jpg
# Loaded and transformed: 0367973.jpg
# Loaded and transformed: 0367768.jpg
# Loaded and transformed: 0994754.jpg
# Loaded and transformed: 0977899.jpg
# Loaded and transformed: 1564412.jpg
# Loaded and transformed: 1943356.jpg
# Loaded and transformed: 0497894.jpg
# Loaded and transformed: 0852827.jpg
# Loaded and transformed: 1672425.jpg
# Loaded and transformed: 0606502.jpg
# Loaded and transformed: 1713232.jpg
# Loaded and transformed: 1009031.jpg
# Loaded and transformed: 1013082.jpg
# Loaded and transformed: 1772155.jpg
# Loaded and transformed: 1420523.jpg
# Loaded and transformed: 0993061.jpg
# Loaded and transformed: 1486858.jpg
# Loaded and transformed: 2161794.jpg
# Loaded and transformed: 1486682.jpg
# Loaded and transformed: 0127637.jpg
# Loaded and transformed: 1036822.jpg
# Loaded and transformed: 2136369.jpg
# Loaded and transformed: 0555526.jpg
# Loaded and transformed: 1097975.jpg
# Loaded and transformed: 1132271.jpg
# Loaded and transformed: 0869722.jpg
# Loaded and transformed: 0744732.jpg
# Loaded and transformed: 1345040.jpg
# Loaded and transformed: 1054081.jpg
# Loaded and transformed: 1469691.jpg
# Loaded and transformed: 2170301.jpg
# Loaded and transformed: 1997878.jpg
# Loaded and transformed: 0901514.jpg
# Loaded and transformed: 1215515.jpg
# Loaded and transformed: 0448006.jpg
# Loaded and transformed: 1092415.jpg
# Loaded and transformed: 0064904.jpg
# Loaded and transformed: 1309306.jpg
# Loaded and transformed: 0425365.jpg
# Loaded and transformed: 0950401.jpg
# Loaded and transformed: 0783526.jpg
# Loaded and transformed: 0876439.jpg
# Loaded and transformed: 2031775.jpg
# Loaded and transformed: 1187431.jpg
# Loaded and transformed: 1018463.jpg
# Loaded and transformed: 0065979.jpg
# Loaded and transformed: 0487316.jpg
# Loaded and transformed: 1498679.jpg
# Loaded and transformed: 1230223.jpg
# Loaded and transformed: 0257378.jpg
# Loaded and transformed: 1865143.jpg
# Loaded and transformed: 0786259.jpg
# Loaded and transformed: 1561989.jpg
# Loaded and transformed: 1198329.jpg
# Loaded and transformed: 0869644.jpg
# Loaded and transformed: 0497885.jpg
# Loaded and transformed: 1758544.jpg
# Loaded and transformed: 1042021.jpg
# Loaded and transformed: 0963590.jpg
# Loaded and transformed: 1002439.jpg
# Loaded and transformed: 0048340.jpg
# Loaded and transformed: 0928792.jpg
# Loaded and transformed: 2147232.jpg
# Loaded and transformed: 0950991.jpg
# Loaded and transformed: 0983934.jpg
# Loaded and transformed: 0681535.jpg
# Loaded and transformed: 0785021.jpg
# Loaded and transformed: 1145144.jpg
# Loaded and transformed: 1831093.jpg
# Loaded and transformed: 1042824.jpg
# Loaded and transformed: 0688093.jpg
# Loaded and transformed: 1828267.jpg
# Loaded and transformed: 2221710.jpg
# Loaded and transformed: 2180833.jpg
# Loaded and transformed: 0454746.jpg
# Loaded and transformed: 0731614.jpg
# Loaded and transformed: 0174885.jpg
# Loaded and transformed: 0894316.jpg
# Loaded and transformed: 0492477.jpg
# Loaded and transformed: 1018861.jpg
# Loaded and transformed: 0957980.jpg
# Loaded and transformed: 1200648.jpg
# Loaded and transformed: 0804670.jpg
# Loaded and transformed: 0687610.jpg
# Loaded and transformed: 0275671.jpg
# Loaded and transformed: 0618871.jpg
# Loaded and transformed: 0766954.jpg
# Loaded and transformed: 2221713.jpg
# Loaded and transformed: 1311419.jpg
# Loaded and transformed: 2091929.jpg
# Loaded and transformed: 1008872.jpg
# Loaded and transformed: 1270583.jpg
# Loaded and transformed: 1427680.jpg
# Loaded and transformed: 1600251.jpg
# Loaded and transformed: 0885966.jpg
# Loaded and transformed: 1455997.jpg
# Loaded and transformed: 1540395.jpg
# Loaded and transformed: 1239223.jpg
# Loaded and transformed: 1284239.jpg
# Loaded and transformed: 1202048.jpg
# Loaded and transformed: 0056978.jpg
# Loaded and transformed: 1166589.jpg
# Loaded and transformed: 1957106.jpg
# Loaded and transformed: 1484700.jpg
# Loaded and transformed: 1423583.jpg
# Loaded and transformed: 1082409.jpg
# Loaded and transformed: 1379818.jpg
# Loaded and transformed: 1245887.jpg
# Loaded and transformed: 1534376.jpg
# Loaded and transformed: 2019594.jpg
# Loaded and transformed: 1563038.jpg
# Loaded and transformed: 0114420.jpg
# Loaded and transformed: 1059813.jpg
# Loaded and transformed: 0718915.jpg
# Loaded and transformed: 0939497.jpg
# Loaded and transformed: 0198433.jpg
# Loaded and transformed: 2079513.jpg
# Loaded and transformed: 1311421.jpg
# Loaded and transformed: 0962875.jpg
# Loaded and transformed: 1702899.jpg
# Loaded and transformed: 0092334.jpg
# Loaded and transformed: 1700644.jpg
# Loaded and transformed: 0859029.jpg
# Loaded and transformed: 1276727.jpg
# Loaded and transformed: 1398832.jpg
# Loaded and transformed: 1539525.jpg
# Loaded and transformed: 1099216.jpg
# Loaded and transformed: 1028187.jpg
# Loaded and transformed: 1446456.jpg
# Loaded and transformed: 1290539.jpg
# Loaded and transformed: 0090864.jpg
# Loaded and transformed: 0094394.jpg
# Loaded and transformed: 0179022.jpg
# Loaded and transformed: 1842078.jpg
# Loaded and transformed: 1928510.jpg
# Loaded and transformed: 1566619.jpg
# Loaded and transformed: 0751325.jpg
# Loaded and transformed: 0522830.jpg
# Loaded and transformed: 1833904.jpg
# Loaded and transformed: 1715316.jpg
# Loaded and transformed: 1037501.jpg
# Loaded and transformed: 1831097.jpg
# Loaded and transformed: 0063286.jpg
# Loaded and transformed: 1094916.jpg
# Loaded and transformed: 0949946.jpg
# Loaded and transformed: 0821422.jpg
# Loaded and transformed: 0064933.jpg
# Loaded and transformed: 1226606.jpg
# Loaded and transformed: 0677583.jpg
# Loaded and transformed: 0202466.jpg
# Loaded and transformed: 1410104.jpg
# Loaded and transformed: 0056299.jpg
# Loaded and transformed: 1195689.jpg
# Loaded and transformed: 0979376.jpg
# Loaded and transformed: 2244841.jpg
# Loaded and transformed: 0582363.jpg
# Loaded and transformed: 1879895.jpg
# Loaded and transformed: 0730970.jpg
# Loaded and transformed: 1093824.jpg
# Loaded and transformed: 0636482.jpg
# Loaded and transformed: 1387195.jpg
# Loaded and transformed: 0951982.jpg
# Loaded and transformed: 0765780.jpg
# Loaded and transformed: 0809727.jpg
# Loaded and transformed: 1340192.jpg
# Loaded and transformed: 1906073.jpg
# Loaded and transformed: 1389219.jpg
# Loaded and transformed: 0983542.jpg
# Loaded and transformed: 1281453.jpg
# Loaded and transformed: 0514738.jpg
# Loaded and transformed: 0299647.jpg
# Loaded and transformed: 0396589.jpg
# Loaded and transformed: 1098609.jpg
# Loaded and transformed: 1062969.jpg
# Loaded and transformed: 0766314.jpg
# Loaded and transformed: 0829998.jpg
# Loaded and transformed: 1143409.jpg
# Loaded and transformed: 0577855.jpg
# Loaded and transformed: 1313523.jpg
# Loaded and transformed: 1245215.jpg
# Loaded and transformed: 1985184.jpg
# Loaded and transformed: 1053425.jpg
# Loaded and transformed: 0203222.jpg
# Loaded and transformed: 2106202.jpg
# Loaded and transformed: 1680778.jpg
# Loaded and transformed: 2047538.jpg
# Loaded and transformed: 0448050.jpg
# Loaded and transformed: 0336925.jpg
# Loaded and transformed: 1008569.jpg
# Loaded and transformed: 0215875.jpg
# Loaded and transformed: 1410102.jpg
# Loaded and transformed: 0482761.jpg
# Loaded and transformed: 0517785.jpg
# Loaded and transformed: 0716386.jpg
# Loaded and transformed: 1749597.jpg
# Loaded and transformed: 1355201.jpg
# Loaded and transformed: 0065292.jpg
# Loaded and transformed: 1630487.jpg
# Loaded and transformed: 1449103.jpg
# Loaded and transformed: 1027362.jpg
# Loaded and transformed: 1326007.jpg
# Loaded and transformed: 1707955.jpg
# Loaded and transformed: 1355200.jpg
# Loaded and transformed: 2197330.jpg
# Loaded and transformed: 1207591.jpg
# Loaded and transformed: 0817494.jpg
# Loaded and transformed: 2041416.jpg
# Loaded and transformed: 0548719.jpg
# Loaded and transformed: 1013358.jpg
# Loaded and transformed: 0926105.jpg
# Loaded and transformed: 0487356.jpg
# Loaded and transformed: 1346444.jpg
# Loaded and transformed: 0698580.jpg
# Loaded and transformed: 1043369.jpg
# Loaded and transformed: 0610657.jpg
# Loaded and transformed: 0582372.jpg
# Loaded and transformed: 0482818.jpg
# Loaded and transformed: 0447749.jpg
# Loaded and transformed: 1464252.jpg
# Loaded and transformed: 0476345.jpg
# Loaded and transformed: 1422830.jpg
# Loaded and transformed: 1111016.jpg
# Loaded and transformed: 1146172.jpg
# Created a tensor of shape: torch.Size([300, 3, 224, 224])

# %%
####################################


#THIS SECOND SECTION WILL IMPORT THE TESTING DATA AND SETUP THE INFORMATION FOR F1 TESTING


####################################

# %%
# Define the classifications and their numeric mappings
classification_mapping = {
    "Boeing 707": 0,
    "Boeing 747": 1,
    "A310": 2,
    "Beechcraft 1900": 3,
    "Gulfstream": 4
}

# File path for the testing data classification file
test_file_path = '/Users/louieburns/Library/CloudStorage/OneDrive-UniversityofLeeds/Year 3/AI and Machine Learning/Term 1/Coursework 1/Actual Coursework/dataoriginal/images_family_test.txt'

# Read and process the testing data file
test_data = []
with open(test_file_path, 'r') as file:
    for i, line in enumerate(file):
        parts = line.strip().split()
        if len(parts) >= 2:  # Ensure there are at least two fields
            number = parts[0]
            classification = ' '.join(parts[1:])  # Combine remaining parts
            test_data.append({"Number": number, "Classification": classification})
        else:
            print(f"Skipping invalid line {i + 1}: {line.strip()}")  # Debugging invalid lines

# Convert to a DataFrame
df_test = pd.DataFrame(test_data)

# Standardise the Classification column
df_test['Classification'] = df_test['Classification'].str.strip()  # Remove extra spaces
df_test['Classification'] = df_test['Classification'].str.title()  # Standardise capitalisation

# Add numeric labels and filter invalid classifications
df_test['Label'] = df_test['Classification'].map(classification_mapping)
df_test = df_test.dropna(subset=['Label']).reset_index(drop=True)  # Remove rows with invalid classifications

# Display the resulting DataFrame
print(df_test)

# Path to the testing images
test_image_folder_path = '/Users/louieburns/Library/CloudStorage/OneDrive-UniversityofLeeds/Year 3/AI and Machine Learning/Term 1/Coursework 1/Actual Coursework/dataoriginal/images'

# Relevant test image codes
relevant_test_codes = set(df_test['Number'])  # Convert to a set for faster lookup

# Initialize a list to hold testing image tensors
test_image_tensors = []

# Define the image transformation (resize and convert to tensor)
transform = transforms.Compose([
    transforms.Resize((224, 224)),  # Resize all images to a fixed size (e.g., 224x224)
    transforms.ToTensor()  # Convert image to PyTorch tensor
])

# Iterate over files in the folder
for image_file in os.listdir(test_image_folder_path):
    # Extract the numeric part of the file name (assuming it's the code)
    code = os.path.splitext(image_file)[0]
    if code in relevant_test_codes and image_file.endswith('.jpg'):
        # Load the image
        image_path = os.path.join(test_image_folder_path, image_file)
        img = Image.open(image_path).convert('RGB')  # Ensure 3 color channels (RGB)
        
        # Transform the image and append to the list
        tensor = transform(img)
        test_image_tensors.append(tensor)
        print(f"Loaded and transformed: {image_file}")

# Stack all tensors into a single tensor
if test_image_tensors:
    test_image_tensor_batch = torch.stack(test_image_tensors)
    print(f"Created a testing tensor of shape: {test_image_tensor_batch.shape}")
else:
    print("No testing images matched the criteria!")

# Example tensor shape: [num_test_images, channels, height, width]
# Out:
#       Number Classification  Label
# 0    1514522     Boeing 707    0.0
# 1    0747566     Boeing 707    0.0
# 2    1008575     Boeing 707    0.0
# 3    0717480     Boeing 707    0.0
# 4    0991569     Boeing 707    0.0
# ..       ...            ...    ...
# 294  0447762     Gulfstream    4.0
# 295  0396507     Gulfstream    4.0
# 296  2030079     Gulfstream    4.0
# 297  1063148     Gulfstream    4.0
# 298  0492487     Gulfstream    4.0
#
# [299 rows x 3 columns]
# Loaded and transformed: 0812092.jpg
# Loaded and transformed: 1698699.jpg
# Loaded and transformed: 1864991.jpg
# Loaded and transformed: 0574359.jpg
# Loaded and transformed: 2211444.jpg
# Loaded and transformed: 1663953.jpg
# Loaded and transformed: 0869743.jpg
# Loaded and transformed: 1272698.jpg
# Loaded and transformed: 0918179.jpg
# Loaded and transformed: 1592286.jpg
# Loaded and transformed: 1767102.jpg
# Loaded and transformed: 0066420.jpg
# Loaded and transformed: 0367786.jpg
# Loaded and transformed: 1686317.jpg
# Loaded and transformed: 0727357.jpg
# Loaded and transformed: 1739526.jpg
# Loaded and transformed: 1237717.jpg
# Loaded and transformed: 1320257.jpg
# Loaded and transformed: 1008575.jpg
# Loaded and transformed: 0543870.jpg
# Loaded and transformed: 0540389.jpg
# Loaded and transformed: 0123340.jpg
# Loaded and transformed: 0338531.jpg
# Loaded and transformed: 0197342.jpg
# Loaded and transformed: 1663372.jpg
# Loaded and transformed: 0495198.jpg
# Loaded and transformed: 0263496.jpg
# Loaded and transformed: 1137626.jpg
# Loaded and transformed: 0894381.jpg
# Loaded and transformed: 0770350.jpg
# Loaded and transformed: 0426810.jpg
# Loaded and transformed: 1237674.jpg
# Loaded and transformed: 0062719.jpg
# Loaded and transformed: 1355218.jpg
# Loaded and transformed: 1950559.jpg
# Loaded and transformed: 2167150.jpg
# Loaded and transformed: 1129974.jpg
# Loaded and transformed: 0935361.jpg
# Loaded and transformed: 0181737.jpg
# Loaded and transformed: 1066524.jpg
# Loaded and transformed: 0814397.jpg
# Loaded and transformed: 0812094.jpg
# Loaded and transformed: 1922915.jpg
# Loaded and transformed: 0497629.jpg
# Loaded and transformed: 1116410.jpg
# Loaded and transformed: 1329664.jpg
# Loaded and transformed: 0885277.jpg
# Loaded and transformed: 0894385.jpg
# Loaded and transformed: 0705084.jpg
# Loaded and transformed: 0717480.jpg
# Loaded and transformed: 1821602.jpg
# Loaded and transformed: 1471641.jpg
# Loaded and transformed: 1195650.jpg
# Loaded and transformed: 1771969.jpg
# Loaded and transformed: 0537688.jpg
# Loaded and transformed: 0181726.jpg
# Loaded and transformed: 0183641.jpg
# Loaded and transformed: 1088415.jpg
# Loaded and transformed: 1292378.jpg
# Loaded and transformed: 0759316.jpg
# Loaded and transformed: 2094829.jpg
# Loaded and transformed: 0946798.jpg
# Loaded and transformed: 1244306.jpg
# Loaded and transformed: 1312418.jpg
# Loaded and transformed: 0104855.jpg
# Loaded and transformed: 0894387.jpg
# Loaded and transformed: 2217964.jpg
# Loaded and transformed: 1094607.jpg
# Loaded and transformed: 1903311.jpg
# Loaded and transformed: 0725155.jpg
# Loaded and transformed: 1513616.jpg
# Loaded and transformed: 1626629.jpg
# Loaded and transformed: 0201677.jpg
# Loaded and transformed: 0836147.jpg
# Loaded and transformed: 1527503.jpg
# Loaded and transformed: 1161004.jpg
# Loaded and transformed: 0989831.jpg
# Loaded and transformed: 1244348.jpg
# Loaded and transformed: 0869735.jpg
# Loaded and transformed: 0091357.jpg
# Loaded and transformed: 1622762.jpg
# Loaded and transformed: 1415611.jpg
# Loaded and transformed: 1818227.jpg
# Loaded and transformed: 1154647.jpg
# Loaded and transformed: 0188405.jpg
# Loaded and transformed: 1650652.jpg
# Loaded and transformed: 1063148.jpg
# Loaded and transformed: 0967862.jpg
# Loaded and transformed: 0127621.jpg
# Loaded and transformed: 0894240.jpg
# Loaded and transformed: 2259299.jpg
# Loaded and transformed: 1338874.jpg
# Loaded and transformed: 0174858.jpg
# Loaded and transformed: 1047407.jpg
# Loaded and transformed: 1145204.jpg
# Loaded and transformed: 1425707.jpg
# Loaded and transformed: 0959346.jpg
# Loaded and transformed: 1313993.jpg
# Loaded and transformed: 0062223.jpg
# Loaded and transformed: 1292533.jpg
# Loaded and transformed: 0958065.jpg
# Loaded and transformed: 1345732.jpg
# Loaded and transformed: 0396119.jpg
# Loaded and transformed: 0396535.jpg
# Loaded and transformed: 2023598.jpg
# Loaded and transformed: 0396525.jpg
# Loaded and transformed: 0143388.jpg
# Loaded and transformed: 0809560.jpg
# Loaded and transformed: 1427673.jpg
# Loaded and transformed: 0492487.jpg
# Loaded and transformed: 1695905.jpg
# Loaded and transformed: 0458628.jpg
# Loaded and transformed: 2160088.jpg
# Loaded and transformed: 0687392.jpg
# Loaded and transformed: 1402021.jpg
# Loaded and transformed: 1453508.jpg
# Loaded and transformed: 1200647.jpg
# Loaded and transformed: 1187784.jpg
# Loaded and transformed: 2102584.jpg
# Loaded and transformed: 2226313.jpg
# Loaded and transformed: 0795231.jpg
# Loaded and transformed: 2127935.jpg
# Loaded and transformed: 1896036.jpg
# Loaded and transformed: 1623096.jpg
# Loaded and transformed: 0901513.jpg
# Loaded and transformed: 1149969.jpg
# Loaded and transformed: 1277988.jpg
# Loaded and transformed: 1077924.jpg
# Loaded and transformed: 1013534.jpg
# Loaded and transformed: 0062769.jpg
# Loaded and transformed: 0783900.jpg
# Loaded and transformed: 1565325.jpg
# Loaded and transformed: 0492490.jpg
# Loaded and transformed: 1619901.jpg
# Loaded and transformed: 2119978.jpg
# Loaded and transformed: 1564952.jpg
# Loaded and transformed: 1173014.jpg
# Loaded and transformed: 1514522.jpg
# Loaded and transformed: 0747566.jpg
# Loaded and transformed: 1351594.jpg
# Loaded and transformed: 1707900.jpg
# Loaded and transformed: 1658586.jpg
# Loaded and transformed: 1336043.jpg
# Loaded and transformed: 1796764.jpg
# Loaded and transformed: 1647303.jpg
# Loaded and transformed: 2030079.jpg
# Loaded and transformed: 0789828.jpg
# Loaded and transformed: 0895165.jpg
# Loaded and transformed: 0457849.jpg
# Loaded and transformed: 0227120.jpg
# Loaded and transformed: 1519194.jpg
# Loaded and transformed: 0764239.jpg
# Loaded and transformed: 1446335.jpg
# Loaded and transformed: 0903308.jpg
# Loaded and transformed: 0964344.jpg
# Loaded and transformed: 0062765.jpg
# Loaded and transformed: 1797113.jpg
# Loaded and transformed: 2223311.jpg
# Loaded and transformed: 1546282.jpg
# Loaded and transformed: 0115062.jpg
# Loaded and transformed: 1385093.jpg
# Loaded and transformed: 1636521.jpg
# Loaded and transformed: 2162684.jpg
# Loaded and transformed: 0693511.jpg
# Loaded and transformed: 0362870.jpg
# Loaded and transformed: 0592099.jpg
# Loaded and transformed: 1041645.jpg
# Loaded and transformed: 1707891.jpg
# Loaded and transformed: 0063295.jpg
# Loaded and transformed: 0926148.jpg
# Loaded and transformed: 1223291.jpg
# Loaded and transformed: 1375148.jpg
# Loaded and transformed: 0658110.jpg
# Loaded and transformed: 0136486.jpg
# Loaded and transformed: 0447936.jpg
# Loaded and transformed: 1415430.jpg
# Loaded and transformed: 1806210.jpg
# Loaded and transformed: 1539455.jpg
# Loaded and transformed: 0890827.jpg
# Loaded and transformed: 0946093.jpg
# Loaded and transformed: 1836113.jpg
# Loaded and transformed: 2180164.jpg
# Loaded and transformed: 1619270.jpg
# Loaded and transformed: 2233262.jpg
# Loaded and transformed: 1091663.jpg
# Loaded and transformed: 0457881.jpg
# Loaded and transformed: 0067035.jpg
# Loaded and transformed: 0602227.jpg
# Loaded and transformed: 1469918.jpg
# Loaded and transformed: 2139678.jpg
# Loaded and transformed: 0104828.jpg
# Loaded and transformed: 1009765.jpg
# Loaded and transformed: 0965713.jpg
# Loaded and transformed: 1450008.jpg
# Loaded and transformed: 1305520.jpg
# Loaded and transformed: 1455400.jpg
# Loaded and transformed: 0457880.jpg
# Loaded and transformed: 0702839.jpg
# Loaded and transformed: 0880576.jpg
# Loaded and transformed: 0064924.jpg
# Loaded and transformed: 0064932.jpg
# Loaded and transformed: 1341837.jpg
# Loaded and transformed: 0536515.jpg
# Loaded and transformed: 0175817.jpg
# Loaded and transformed: 0396507.jpg
# Loaded and transformed: 1354235.jpg
# Loaded and transformed: 0851311.jpg
# Loaded and transformed: 1400629.jpg
# Loaded and transformed: 1776868.jpg
# Loaded and transformed: 0136480.jpg
# Loaded and transformed: 0454743.jpg
# Loaded and transformed: 0869739.jpg
# Loaded and transformed: 1106454.jpg
# Loaded and transformed: 1645736.jpg
# Loaded and transformed: 1921656.jpg
# Loaded and transformed: 0082497.jpg
# Loaded and transformed: 0064890.jpg
# Loaded and transformed: 0939480.jpg
# Loaded and transformed: 0467411.jpg
# Loaded and transformed: 0688083.jpg
# Loaded and transformed: 0368357.jpg
# Loaded and transformed: 0383679.jpg
# Loaded and transformed: 0980549.jpg
# Loaded and transformed: 0636590.jpg
# Loaded and transformed: 0155579.jpg
# Loaded and transformed: 0668306.jpg
# Loaded and transformed: 0149352.jpg
# Loaded and transformed: 0751008.jpg
# Loaded and transformed: 0062672.jpg
# Loaded and transformed: 0115565.jpg
# Loaded and transformed: 0525862.jpg
# Loaded and transformed: 0422472.jpg
# Loaded and transformed: 0973263.jpg
# Loaded and transformed: 0618964.jpg
# Loaded and transformed: 0498138.jpg
# Loaded and transformed: 0540023.jpg
# Loaded and transformed: 2230119.jpg
# Loaded and transformed: 0979377.jpg
# Loaded and transformed: 1663379.jpg
# Loaded and transformed: 0929568.jpg
# Loaded and transformed: 1036862.jpg
# Loaded and transformed: 0939547.jpg
# Loaded and transformed: 1624193.jpg
# Loaded and transformed: 0947462.jpg
# Loaded and transformed: 0482823.jpg
# Loaded and transformed: 1645747.jpg
# Loaded and transformed: 0691159.jpg
# Loaded and transformed: 0598112.jpg
# Loaded and transformed: 1409250.jpg
# Loaded and transformed: 2099873.jpg
# Loaded and transformed: 0991569.jpg
# Loaded and transformed: 1244687.jpg
# Loaded and transformed: 0337959.jpg
# Loaded and transformed: 0302935.jpg
# Loaded and transformed: 1337523.jpg
# Loaded and transformed: 0894203.jpg
# Loaded and transformed: 0699302.jpg
# Loaded and transformed: 1627935.jpg
# Loaded and transformed: 0948344.jpg
# Loaded and transformed: 0989281.jpg
# Loaded and transformed: 0733462.jpg
# Loaded and transformed: 0730396.jpg
# Loaded and transformed: 0487369.jpg
# Loaded and transformed: 1572354.jpg
# Loaded and transformed: 1340195.jpg
# Loaded and transformed: 0071754.jpg
# Loaded and transformed: 0093510.jpg
# Loaded and transformed: 0065286.jpg
# Loaded and transformed: 1985180.jpg
# Loaded and transformed: 1300002.jpg
# Loaded and transformed: 0447762.jpg
# Loaded and transformed: 1425231.jpg
# Loaded and transformed: 1125617.jpg
# Loaded and transformed: 0485231.jpg
# Loaded and transformed: 1124247.jpg
# Loaded and transformed: 1362533.jpg
# Loaded and transformed: 1149068.jpg
# Loaded and transformed: 2106207.jpg
# Loaded and transformed: 1191359.jpg
# Loaded and transformed: 0978286.jpg
# Loaded and transformed: 0306188.jpg
# Loaded and transformed: 0677586.jpg
# Loaded and transformed: 0812908.jpg
# Loaded and transformed: 0934703.jpg
# Loaded and transformed: 1500676.jpg
# Loaded and transformed: 0725997.jpg
# Loaded and transformed: 0894166.jpg
# Loaded and transformed: 0127505.jpg
# Loaded and transformed: 1505652.jpg
# Loaded and transformed: 1860132.jpg
# Loaded and transformed: 0641196.jpg
# Loaded and transformed: 0175726.jpg
# Loaded and transformed: 1081565.jpg
# Loaded and transformed: 1685202.jpg
# Loaded and transformed: 0126154.jpg
# Loaded and transformed: 0337963.jpg
# Loaded and transformed: 1231746.jpg
# Loaded and transformed: 0606801.jpg
# Loaded and transformed: 1614686.jpg
# Created a testing tensor of shape: torch.Size([299, 3, 224, 224])

# %%
####################################


#THIS 3rd SECTION WILL SETUP AND TRAIN THE NEURAL NETWORK

####################################

# %%
import torch.nn as nn
import torch.nn.functional as F

# Define a simple neural network architecture
class SimpleAircraftClassifier(nn.Module):
    def __init__(self, input_size=3*224*224, num_classes=5):  # Default assumes 224x224 RGB images
        super(SimpleAircraftClassifier, self).__init__()
        
# Add another hidden layer
        self.fc1 = nn.Linear(input_size, 256)  # First fully connected layer
        self.fc2 = nn.Linear(256, 128)        # Second fully connected layer
        self.fc3 = nn.Linear(128, num_classes)  # Output layer
        
    def forward(self, x):
        # Flatten the input
        x = x.view(x.size(0), -1)  # Reshape the tensor to (batch_size, input_size)
        
        # Apply fully connected layers with ReLU activation
        x = F.relu(self.fc1(x))
        x = F.relu(self.fc2(x))
        x = self.fc3(x)
        
        return x

# Instantiate the model
input_size = 3 * 224 * 224  # Flattened size of 224x224 RGB images
num_classes = len(classification_mapping)  # Number of classes (5 based on your mapping)
simple_model = SimpleAircraftClassifier(input_size=input_size, num_classes=num_classes)

# Print model summary
print(simple_model)


# Define the loss function and optimizer
criterion = nn.CrossEntropyLoss()
optimizer = torch.optim.Adam(simple_model.parameters(), lr=0.001)

# Training function remains the same
def train_simple_model(model, train_loader, criterion, optimizer, num_epochs=10):
    model.train()  # Set the model to training mode
    for epoch in range(num_epochs):
        running_loss = 0.0
        for images, labels in train_loader:
            # Flatten images to fit the simple model
            images = images.view(images.size(0), -1)
            
            # Zero the parameter gradients
            optimizer.zero_grad()
            
            # Forward pass
            outputs = model(images)
            loss = criterion(outputs, labels)
            
            # Backward pass and optimization
            loss.backward()
            optimizer.step()
            
            # Track loss
            running_loss += loss.item()
        
        print(f"Epoch {epoch+1}/{num_epochs}, Loss: {running_loss / len(train_loader)}")

# Example DataLoader creation
from torch.utils.data import DataLoader, TensorDataset

# Prepare dataset and loader
train_dataset = TensorDataset(image_tensor_batch, torch.tensor(df['Label'].values, dtype=torch.long))
train_loader = DataLoader(train_dataset, batch_size=32, shuffle=True)


# Train the simple model
train_simple_model(simple_model, train_loader, criterion, optimizer, num_epochs=10)
# Out:
# SimpleAircraftClassifier(
#   (fc1): Linear(in_features=150528, out_features=256, bias=True)
#   (fc2): Linear(in_features=256, out_features=128, bias=True)
#   (fc3): Linear(in_features=128, out_features=5, bias=True)
# )
# Epoch 1/10, Loss: 16.222561132907867
# Epoch 2/10, Loss: 7.907152795791626
# Epoch 3/10, Loss: 4.617014455795288
# Epoch 4/10, Loss: 2.073240226507187
# Epoch 5/10, Loss: 2.018816518783569
# Epoch 6/10, Loss: 2.0273361206054688
# Epoch 7/10, Loss: 1.533750557899475
# Epoch 8/10, Loss: 1.314308762550354
# Epoch 9/10, Loss: 1.224974811077118
# Epoch 10/10, Loss: 1.5893061876296997

# %%
####################################


#THIS 4th SECTION COMPLETES AN F1 TEST ON THE TRAINING DATA

####################################

# %%
# Define the testing function
def evaluate_model(model, test_loader):
    model.eval()  # Set the model to evaluation mode
    all_labels = []
    all_preds = []
    
    with torch.no_grad():  # No gradient calculation needed during testing
        for images, labels in test_loader:
            # Flatten images for the simple model
            images = images.view(images.size(0), -1)  # Reshape images for simple model
            
            # Forward pass
            outputs = model(images)
            
            # Get predictions (class with the highest score)
            _, preds = torch.max(outputs, 1)
            
            # Store predictions and labels
            all_preds.extend(preds.cpu().numpy())
            all_labels.extend(labels.cpu().numpy())
    
    # Calculate Weighted F1-Score
    f1 = f1_score(all_labels, all_preds, average='weighted')
    print(f"Weighted F1-Score: {f1}")
    
    return f1

# Prepare DataLoader for testing data
test_dataset = TensorDataset(test_image_tensor_batch, torch.tensor(df_test['Label'].values, dtype=torch.long))
test_loader = DataLoader(test_dataset, batch_size=32, shuffle=False)

# Evaluate the model on testing data
f1_score_test = evaluate_model(simple_model, test_loader)
# Out:
# Weighted F1-Score: 0.2758334617446431
