# %% [markdown]
#  ## Task 1
#  We will use the Cifar-10 dataset, which consists of 60,000 32x32 color images in 10 different classes. desing a neural network architecture using the pytorch library and show the traning performance of the network and evaulation of the network.

# %% [markdown]
# ## Import Libraries

# %% [markdown]
# ## Load Data Set
# *   Load the Aircraft dataset
# *   Split into training and testing segments
#   * The training segment is used for training the model, while the testing portion of the data is used to evaluate the accuracy of our model.

# %% [markdown]
# ## Preprocess the dataset
# Preprocess the dataset by normalizing the pixel values between 0 and 1.

# %%
#type your code here

# %% [markdown]
# ## Creating the model

# %%
#type you code here

# %% [markdown]
# ### Compiling the model using your choosen optimisation method

# %%
#type you code here

# %% [markdown]
# ### Training the model

# %%
#type your code here

# %% [markdown]
# ### Evaluating the model

# %%
# Evaluate the model

# %% [markdown]
# ## Optimised model
#
# * Creates a optimised model.

# %%
#type your code here

# %% [markdown]
# ## Comprehensive evaluation
#
# use markdown section to write comprehensive evaluation metrics, such as accuracy, precision, recall, and F1 score. Additionally, include a confusion matrix to understand the model's performance.

# %% [markdown]
# ## Task 2
# In this task you wil train the MSTR dataset using pytorch and train a Convolutional Neural Network (CNN) to classify the MSTR dataset using weighted F1 score. You should train the model using a GPU if available.
